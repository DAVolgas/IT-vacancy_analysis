# %%
import aiohttp
import asyncio
import pandas as pd
import random
import time
from datetime import datetime, timedelta, timezone
import logging

# %%
# === Настройки ===
header = {'User-Agent': 'HH-Data-Coll/v2.0 (contact 135861v@mail.ru)'}
area_id_russia = 113
per_page = 100
max_pages = 100
semaphore = asyncio.Semaphore(5)

# Опыт
experiences = ['noExperience', 'between1And3', 'between3And6', 'moreThan6']

# Настройки логгирования
log_filename = f"hh_parser_log_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",  
    handlers=[
        logging.FileHandler(log_filename, encoding="utf-8"), 
        logging.StreamHandler()
    ]
)

def log_elapsed_time(start, task="Code"):
    end = time.perf_counter()
    elapsed = end - start
    mins, secs = divmod(elapsed, 60)
    hrs, mins = divmod(mins, 60)
    logging.info(f"⏱ Время выполнения ({task}): {int(hrs):02d}:{int(mins):02d}:{secs:.2f} секунд")


# Период: последние 30 дней с шагом 7 дней
def get_date_ranges(days=30, step=7):
    today = datetime.now(timezone.utc).date()
    start_date = today - timedelta(days=days)
    ranges = []
    current = start_date
    while current < today:
        end = min(current + timedelta(days=step), today)
        ranges.append((current.isoformat(), end.isoformat()))
        current = end
    return ranges

# Загрузка справочников для валидации данных
async def fetch_reference_data():
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get('https://api.hh.ru/dictionaries') as resp:
            dict_data = await resp.json()

        async with session.get('https://api.hh.ru/areas') as resp:
            area_data = await resp.json()
            area_ids = set()

            def extract_area_ids(areas):
                for a in areas:
                    area_ids.add(str(a['id']))
                    if 'areas' in a and a['areas']:
                        extract_area_ids(a['areas'])

            extract_area_ids(area_data)

        return {
            'experience': {e['name'] for e in dict_data['experience']},
            'employment': {e['name'] for e in dict_data['employment']},
            'schedule': {e['name'] for e in dict_data['schedule']},
            'area_ids': area_ids
        }

# RateLimiter
class RateLimiter:
    def __init__(self, max_rps=3, long_pause_every=500, long_pause_duration=60):
        self.max_rps = max_rps
        self.long_pause_every = long_pause_every
        self.long_pause_duration = long_pause_duration
        self.last_request = None
        self.request_count = 0
        self.lock = asyncio.Lock()

    async def wait(self):
        async with self.lock:
            now = time.monotonic()
            if self.last_request is not None:
                elapsed = now - self.last_request
                delay = max(0, 1.0 / self.max_rps - elapsed)
                if delay > 0:
                    await asyncio.sleep(delay)
            self.last_request = time.monotonic()
            self.request_count += 1
            if self.request_count % self.long_pause_every == 0:
                logging.info(f"Долгая пауза {self.long_pause_duration} сек после {self.request_count} запросов...")
                await asyncio.sleep(self.long_pause_duration)

limiter = RateLimiter()

# %%
#=== Функции сбора вакансий ===
# Получение IT-ролей
async def fetch_it_roles():
    url = 'https://api.hh.ru/professional_roles'
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get(url) as response:
            response.raise_for_status()
            data = await response.json()
            for cat in data['categories']:
                if int(cat['id']) == 11:
                    roles = [
                        {'id': int(role['id']), 'name': role['name']}
                        for role in cat['roles']
                        if int(role['id']) not in [12, 25, 34, 155]
                    ]
                    logging.info(f'🔹 Найдено {len(roles)} IT-ролей')
                    return roles
            return []

# Загрузка одной страницы с повторными попытками
async def fetch_page(session, params, page, desc, max_retries=3):
    params['page'] = page
    for attempt in range(1, max_retries + 1):
        await limiter.wait()
        try:
            async with semaphore:
                async with session.get('https://api.hh.ru/vacancies', params=params) as response:
                    if response.status == 403:
                        logging.warning(f"🚫 Ошибка 403 на странице {page} — {desc} (попытка {attempt})")
                    elif response.status >= 400:
                        logging.warning(f"⚠️ Ошибка {response.status} на странице {page} — {desc} (попытка {attempt})")
                    response.raise_for_status()
                    return await response.json()
        except Exception as e:
            logging.warning(f"⚠️ Исключение при загрузке страницы {page} — {desc} (попытка {attempt}): {e}")
            await asyncio.sleep(random.uniform(1.0, 2.0))

    error_msg = f"❌ Ошибка: не удалось загрузить страницу {page} — {desc} после {max_retries} попыток. Остановка."
    logging.error(error_msg)
    raise RuntimeError(error_msg)

# Сбор вакансий по комбинации ролей, опыта и дат
async def fetch_vacancies(session, role_id, role_name, experience, date_from, date_to):
    desc = f"роль '{role_name}', опыт '{experience}', {date_from}–{date_to}"
    vacancies = []
    params = {
        'professional_role': role_id,
        'area': area_id_russia,
        'experience': experience,
        'date_from': date_from,
        'date_to': date_to,
        'per_page': per_page,
    }

    for page in range(max_pages):
        data = await fetch_page(session, params, page, desc)
        if data is None:
            break
        items = data.get('items', [])
        if not items:
            break
        vacancies.extend(items)
        if page >= data.get('pages', 0) - 1:
            break
        await asyncio.sleep(random.uniform(0.3, 0.6))

    logging.info(f"✅ Собрано {len(vacancies)} вакансий — {desc}")
    return vacancies

# Основной сбор данных
async def collect_vacancies_async():
    all_vacancies = []
    date_ranges = get_date_ranges()
    roles = await fetch_it_roles()

    try:
        async with aiohttp.ClientSession(headers=header) as session:
            for role in roles:
                logging.info(f"\n== Роль: {role['name']} (ID {role['id']}) ==")
                for exp in experiences:
                    for date_from, date_to in date_ranges:
                        batch = await fetch_vacancies(session, role['id'], role['name'], exp, date_from, date_to)
                        all_vacancies.extend(batch)

    except RuntimeError as critical_error:
        logging.critical(f"🚨 Парсинг прерван: {critical_error}")
        raise  

    # logging.info(f"\n🚀 Всего собрано {len(all_vacancies)} вакансий")
    return all_vacancies

# Преобразование вакансий в DataFrame
def extract_vacancy_data(raw_vacancies):
    extracted = []
    for v in raw_vacancies:
        area_info = v.get('area', {})
        salary_range = v.get('salary_range') or {}
        
        extracted.append({
            'load_datetime': datetime.now(),
            'professional_role': v.get('professional_roles', [{}])[0].get('name') 
                                 if v.get('professional_roles') else None,
            'id': v.get('id'),
            'name': v.get('name'),
            'area': area_info.get('name'),
            'area_id': area_info.get('id'),
            'employer': v.get('employer', {}).get('name'),
            'accredited_it_employer': v.get('employer', {}).get('accredited_it_employer'),
            'trusted_employer': v.get('employer', {}).get('trusted'),
            'published_at': v.get('published_at'),
            'created_at': v.get('created_at'),
            'closed_at': v.get('closed_at'),
            'archived': v.get('archived'),
            'url': v.get('alternate_url'),
            'salary_from': v.get('salary', {}).get('from') if v.get('salary') else None,
            'salary_to': v.get('salary', {}).get('to') if v.get('salary') else None,
            'currency': v.get('salary', {}).get('currency') if v.get('salary') else None,
            'salary_mode': (salary_range.get('mode') or {}).get('name'),        # За месяц, за час...
            'salary_frequency': (salary_range.get('frequency') or {}).get('name'),  # Раз в месяц и т.п.
            'experience': v.get('experience', {}).get('name'),
            'schedule': v.get('schedule', {}).get('name'),
            'employment': v.get('employment', {}).get('name'),
        })
    return pd.DataFrame(extracted).drop_duplicates('id', keep='last')


# Валидация данных
def validate_vacancies(df: pd.DataFrame, dicts: dict):
    required_fields = ['id', 'name', 'area', 'area_id', 'published_at']
    errors = []

    def is_empty(val):
        return val is None or val == "" or (isinstance(val, list) and len(val) == 0)

    invalid_rows = []

    for i, row in df.iterrows():
        row_errors = []

        # Проверка обязательных полей на пустоту
        for field in required_fields:
            if field not in row or is_empty(row[field]):
                row_errors.append(f"Пустое обязательное поле '{field}'")

        # Проверка значений из справочников
        if 'experience' in row and row['experience'] not in dicts['experience'] and not is_empty(row['experience']):
            row_errors.append(f"Неизвестное experience: {row['experience']}")
        if 'employment' in row and row['employment'] not in dicts['employment'] and not is_empty(row['employment']):
            row_errors.append(f"Неизвестное employment: {row['employment']}")
        if 'schedule' in row and row['schedule'] not in dicts['schedule'] and not is_empty(row['schedule']):
            row_errors.append(f"Неизвестное schedule: {row['schedule']}")
        if 'area_id' in row and str(row['area_id']) not in dicts['area_ids'] and not is_empty(row['area_id']):
            row_errors.append(f"Неизвестный area_id: {row['area_id']}")

        if row_errors:
            errors.append((i, row_errors))
            invalid_rows.append(i)

    if errors:
        for i, errs in errors:
            logging.warning(f"Строка {i} отклонена: {', '.join(errs)}")

    reject_df = df.loc[invalid_rows].copy()
    valid_df = df.drop(index=invalid_rows).reset_index(drop=True)

    return valid_df.reset_index(drop=True), reject_df.reset_index(drop=True)

# %%
# Запуск сбора вакансий
start = time.perf_counter()

raw_vacancies = await collect_vacancies_async()
df = extract_vacancy_data(raw_vacancies)

reference_data = await fetch_reference_data()
valid_df, reject_df = validate_vacancies(df, reference_data)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
reject_filename = f"rejected_vacancies_{timestamp}_reject.csv"
if not reject_df.empty:
    reject_df.to_csv(reject_filename, index=False)
    logging.info(f"\n🚫 {len(reject_df)} вакансий отклонено и сохранено в файл {reject_filename}")
else:
    logging.info("\n✅ Все вакансии прошли валидацию. Reject-файл не создан.")


logging.info(f"\n🚀 Всего собрано вакансий: {len(raw_vacancies)}")
logging.info(f"📦 Загружено уникальных id: {valid_df['id'].nunique()}")

log_elapsed_time(start, "hh_parser")
# Out:
# 2025-08-25 12:40:40,050 [INFO] 🔹 Найдено 21 IT-ролей
# 2025-08-25 12:40:40,056 [INFO]
# == Роль: BI-аналитик, аналитик данных (ID 156) ==
# 2025-08-25 12:40:40,456 [INFO] ✅ Собрано 14 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:40:40,798 [INFO] ✅ Собрано 45 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:40:41,248 [INFO] ✅ Собрано 27 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:40:41,630 [INFO] ✅ Собрано 38 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:40:41,855 [INFO] ✅ Собрано 21 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:40:42,525 [INFO] ✅ Собрано 90 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:40:43,962 [INFO] ✅ Собрано 109 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:40:45,316 [INFO] ✅ Собрано 118 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:40:46,903 [INFO] ✅ Собрано 184 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:40:47,292 [INFO] ✅ Собрано 76 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:40:47,656 [INFO] ✅ Собрано 60 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:40:48,125 [INFO] ✅ Собрано 98 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:40:49,585 [INFO] ✅ Собрано 122 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:40:51,129 [INFO] ✅ Собрано 158 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:40:51,508 [INFO] ✅ Собрано 47 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:40:51,730 [INFO] ✅ Собрано 9 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:40:52,052 [INFO] ✅ Собрано 5 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:40:52,477 [INFO] ✅ Собрано 13 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:40:52,738 [INFO] ✅ Собрано 17 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:40:53,070 [INFO] ✅ Собрано 7 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:40:53,074 [INFO]
# == Роль: DevOps-инженер (ID 160) ==
# 2025-08-25 12:40:53,400 [INFO] ✅ Собрано 7 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:40:53,736 [INFO] ✅ Собрано 3 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:40:54,056 [INFO] ✅ Собрано 5 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:40:54,496 [INFO] ✅ Собрано 12 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:40:54,742 [INFO] ✅ Собрано 4 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:40:55,176 [INFO] ✅ Собрано 33 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:40:55,653 [INFO] ✅ Собрано 45 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:40:56,087 [INFO] ✅ Собрано 64 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:40:56,673 [INFO] ✅ Собрано 80 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:40:57,067 [INFO] ✅ Собрано 33 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:40:57,542 [INFO] ✅ Собрано 95 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:40:58,786 [INFO] ✅ Собрано 124 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:00,132 [INFO] ✅ Собрано 127 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:02,604 [INFO] ✅ Собрано 218 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:03,007 [INFO] ✅ Собрано 81 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:03,373 [INFO] ✅ Собрано 21 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:41:03,685 [INFO] ✅ Собрано 27 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:04,006 [INFO] ✅ Собрано 27 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:04,315 [INFO] ✅ Собрано 29 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:04,749 [INFO] ✅ Собрано 15 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:04,750 [INFO]
# == Роль: Аналитик (ID 10) ==
# 2025-08-25 12:41:05,155 [INFO] ✅ Собрано 55 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:41:05,619 [INFO] ✅ Собрано 71 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:41:07,010 [INFO] ✅ Собрано 125 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:41:08,412 [INFO] ✅ Собрано 122 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:41:08,903 [INFO] ✅ Собрано 49 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:41:11,597 [INFO] ✅ Собрано 250 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:41:14,834 [INFO] ✅ Собрано 325 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:41:19,091 [INFO] ✅ Собрано 411 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:41:25,415 [INFO] ✅ Собрано 588 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:41:27,733 [INFO] ✅ Собрано 299 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:41:29,422 [INFO] ✅ Собрано 150 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:41:31,999 [INFO] ✅ Собрано 203 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:34,003 [INFO] ✅ Собрано 246 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:37,398 [INFO] ✅ Собрано 385 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:38,856 [INFO] ✅ Собрано 167 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:39,212 [INFO] ✅ Собрано 17 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:41:39,588 [INFO] ✅ Собрано 25 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:39,993 [INFO] ✅ Собрано 19 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:40,362 [INFO] ✅ Собрано 29 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:40,626 [INFO] ✅ Собрано 7 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:40,627 [INFO]
# == Роль: Бизнес-аналитик (ID 150) ==
# 2025-08-25 12:41:40,971 [INFO] ✅ Собрано 16 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:41:41,347 [INFO] ✅ Собрано 10 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:41:41,638 [INFO] ✅ Собрано 17 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:41:42,031 [INFO] ✅ Собрано 33 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:41:42,330 [INFO] ✅ Собрано 15 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:41:43,159 [INFO] ✅ Собрано 95 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:41:44,537 [INFO] ✅ Собрано 126 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:41:46,076 [INFO] ✅ Собрано 157 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:41:48,531 [INFO] ✅ Собрано 201 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:41:49,054 [INFO] ✅ Собрано 81 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:41:49,631 [INFO] ✅ Собрано 90 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:41:51,117 [INFO] ✅ Собрано 116 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:52,408 [INFO] ✅ Собрано 134 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:53,849 [INFO] ✅ Собрано 182 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:54,382 [INFO] ✅ Собрано 69 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:54,882 [INFO] ✅ Собрано 8 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:41:55,129 [INFO] ✅ Собрано 6 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:41:55,497 [INFO] ✅ Собрано 8 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:41:55,765 [INFO] ✅ Собрано 12 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:41:56,109 [INFO] ✅ Собрано 1 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:41:56,109 [INFO]
# == Роль: Дата-сайентист (ID 165) ==
# 2025-08-25 12:41:56,440 [INFO] ✅ Собрано 2 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:41:56,783 [INFO] ✅ Собрано 14 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:41:57,118 [INFO] ✅ Собрано 7 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:41:57,472 [INFO] ✅ Собрано 5 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:41:57,741 [INFO] ✅ Собрано 0 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:41:58,281 [INFO] ✅ Собрано 17 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:41:58,676 [INFO] ✅ Собрано 45 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:41:59,125 [INFO] ✅ Собрано 46 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:41:59,507 [INFO] ✅ Собрано 52 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:41:59,838 [INFO] ✅ Собрано 25 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:42:00,421 [INFO] ✅ Собрано 47 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:00,883 [INFO] ✅ Собрано 93 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:01,348 [INFO] ✅ Собрано 81 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:02,552 [INFO] ✅ Собрано 104 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:03,036 [INFO] ✅ Собрано 38 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:03,419 [INFO] ✅ Собрано 10 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:03,715 [INFO] ✅ Собрано 12 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:03,996 [INFO] ✅ Собрано 6 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:04,338 [INFO] ✅ Собрано 22 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:04,687 [INFO] ✅ Собрано 6 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:04,689 [INFO]
# == Роль: Директор по информационным технологиям (CIO) (ID 36) ==
# 2025-08-25 12:42:04,909 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:42:05,478 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:42:05,640 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:42:06,022 [INFO] ✅ Собрано 2 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:42:06,412 [INFO] ✅ Собрано 2 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:42:06,743 [INFO] ✅ Собрано 1 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:42:07,033 [INFO] ✅ Собрано 2 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:42:07,704 [INFO] ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:42:07,921 [INFO] ✅ Собрано 6 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:42:08,256 [INFO] ✅ Собрано 2 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:42:08,615 [INFO] ✅ Собрано 17 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:08,972 [INFO] ✅ Собрано 16 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:09,507 [INFO] ✅ Собрано 19 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:09,855 [INFO] ✅ Собрано 39 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:10,171 [INFO] ✅ Собрано 15 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:10,463 [INFO] ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:10,782 [INFO] ✅ Собрано 7 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:11,178 [INFO] ✅ Собрано 14 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:11,461 [INFO] ✅ Собрано 21 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:11,775 [INFO] ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:11,775 [INFO]
# == Роль: Менеджер продукта (ID 73) ==
# 2025-08-25 12:42:12,117 [INFO] ✅ Собрано 12 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:42:12,955 [INFO] ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:42:13,282 [INFO] ✅ Собрано 24 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:42:13,700 [INFO] ✅ Собрано 40 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:42:14,037 [INFO] ✅ Собрано 25 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:42:15,485 [INFO] ✅ Собрано 104 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:42:17,137 [INFO] ✅ Собрано 140 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:42:18,637 [INFO] ✅ Собрано 181 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:42:22,325 [INFO] ✅ Собрано 302 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:42:23,905 [INFO] ✅ Собрано 148 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:42:25,558 [INFO] ✅ Собрано 108 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:26,955 [INFO] ✅ Собрано 133 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:28,762 [INFO] ✅ Собрано 179 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:31,109 [INFO] ✅ Собрано 270 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:32,750 [INFO] ✅ Собрано 142 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:33,085 [INFO] ✅ Собрано 18 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:42:33,498 [INFO] ✅ Собрано 28 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:42:33,840 [INFO] ✅ Собрано 28 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:42:34,183 [INFO] ✅ Собрано 46 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:42:34,572 [INFO] ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:42:34,573 [INFO]
# == Роль: Программист, разработчик (ID 96) ==
# 2025-08-25 12:42:35,830 [INFO] ✅ Собрано 112 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:42:37,433 [INFO] ✅ Собрано 126 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:42:39,159 [INFO] ✅ Собрано 159 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:42:42,477 [INFO] ✅ Собрано 272 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:42:43,773 [INFO] ✅ Собрано 111 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:42:49,183 [INFO] ✅ Собрано 586 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:42:57,055 [INFO] ✅ Собрано 774 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:43:08,050 [INFO] ✅ Собрано 935 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:43:22,935 [INFO] ✅ Собрано 1423 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:43:31,016 [INFO] ✅ Собрано 790 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:43:38,420 [INFO] ✅ Собрано 702 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:43:48,142 [INFO] ✅ Собрано 884 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:43:59,563 [INFO] ✅ Собрано 1044 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:15,851 [INFO] ✅ Собрано 1598 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:24,084 [INFO] ✅ Собрано 805 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:25,711 [INFO] ✅ Собрано 113 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:27,340 [INFO] ✅ Собрано 184 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:28,881 [INFO] ✅ Собрано 200 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:32,085 [INFO] ✅ Собрано 315 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:33,429 [INFO] ✅ Собрано 169 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:33,430 [INFO]
# == Роль: Продуктовый аналитик (ID 164) ==
# 2025-08-25 12:44:33,635 [INFO] ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:44:34,275 [INFO] ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:44:34,483 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:44:34,889 [INFO] ✅ Собрано 5 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:44:35,290 [INFO] ✅ Собрано 3 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:44:35,663 [INFO] ✅ Собрано 37 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:44:36,020 [INFO] ✅ Собрано 40 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:44:36,284 [INFO] ✅ Собрано 26 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:44:36,754 [INFO] ✅ Собрано 50 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:44:37,028 [INFO] ✅ Собрано 21 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:44:37,788 [INFO] ✅ Собрано 25 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:38,203 [INFO] ✅ Собрано 40 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:38,652 [INFO] ✅ Собрано 39 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:39,117 [INFO] ✅ Собрано 46 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:39,354 [INFO] ✅ Собрано 17 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:39,785 [INFO] ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:40,008 [INFO] ✅ Собрано 3 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:40,310 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:40,683 [INFO] ✅ Собрано 11 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:41,019 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:41,021 [INFO]
# == Роль: Руководитель группы разработки (ID 104) ==
# 2025-08-25 12:44:41,325 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:44:41,662 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:44:42,213 [INFO] ✅ Собрано 4 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:44:42,507 [INFO] ✅ Собрано 6 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:44:42,744 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:44:43,139 [INFO] ✅ Собрано 21 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:44:43,652 [INFO] ✅ Собрано 26 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:44:43,966 [INFO] ✅ Собрано 25 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:44:44,301 [INFO] ✅ Собрано 24 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:44:44,538 [INFO] ✅ Собрано 15 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:44:45,078 [INFO] ✅ Собрано 57 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:45,487 [INFO] ✅ Собрано 73 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:46,811 [INFO] ✅ Собрано 103 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:48,403 [INFO] ✅ Собрано 145 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:48,888 [INFO] ✅ Собрано 71 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:49,348 [INFO] ✅ Собрано 46 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:49,833 [INFO] ✅ Собрано 61 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:50,272 [INFO] ✅ Собрано 55 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:51,729 [INFO] ✅ Собрано 104 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:52,138 [INFO] ✅ Собрано 51 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:52,139 [INFO]
# == Роль: Руководитель отдела аналитики (ID 157) ==
# 2025-08-25 12:44:52,319 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:44:52,735 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:44:53,032 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:44:53,367 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:44:53,656 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:44:54,074 [INFO] ✅ Собрано 7 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:44:54,509 [INFO] ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:44:54,761 [INFO] ✅ Собрано 5 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:44:55,268 [INFO] ✅ Собрано 35 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:44:55,530 [INFO] ✅ Собрано 7 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:44:55,945 [INFO] ✅ Собрано 18 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:56,444 [INFO] ✅ Собрано 29 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:57,007 [INFO] ✅ Собрано 31 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:57,439 [INFO] ✅ Собрано 60 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:57,891 [INFO] ✅ Собрано 27 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:58,171 [INFO] ✅ Собрано 7 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:44:58,432 [INFO] ✅ Собрано 6 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:44:58,791 [INFO] ✅ Собрано 14 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:44:59,284 [INFO] ✅ Собрано 12 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:44:59,455 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:44:59,458 [INFO]
# == Роль: Руководитель проектов (ID 107) ==
# 2025-08-25 12:44:59,956 [INFO] ✅ Собрано 24 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:45:00,352 [INFO] ✅ Собрано 39 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:45:00,724 [INFO] ✅ Собрано 48 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:45:01,159 [INFO] ✅ Собрано 73 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:45:01,537 [INFO] ✅ Собрано 36 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:45:03,983 [INFO] ✅ Собрано 282 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:45:07,727 [INFO] ✅ Собрано 342 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:45:12,446 [INFO] ✅ Собрано 420 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:45:19,847 [INFO] ✅ Собрано 694 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:45:23,372 [INFO] ✅ Собрано 352 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:45:26,939 [INFO] ✅ Собрано 307 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:45:30,921 [INFO] ✅ Собрано 390 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:45:35,298 [INFO] ✅ Собрано 479 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:45:42,092 [INFO] ✅ Собрано 647 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:45:45,691 [INFO] ✅ Собрано 321 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:45:46,172 [INFO] ✅ Собрано 76 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:45:46,661 [INFO] ✅ Собрано 80 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:45:47,150 [INFO] ✅ Собрано 74 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:45:47,678 [INFO] ✅ Собрано 99 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:45:48,200 [INFO] ✅ Собрано 61 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:45:48,201 [INFO]
# == Роль: Сетевой инженер (ID 112) ==
# 2025-08-25 12:45:48,436 [INFO] ✅ Собрано 14 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:45:48,887 [INFO] ✅ Собрано 17 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:45:49,202 [INFO] ✅ Собрано 16 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:45:49,733 [INFO] ✅ Собрано 25 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:45:50,008 [INFO] ✅ Собрано 17 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:45:50,510 [INFO] ✅ Собрано 58 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:45:51,087 [INFO] ✅ Собрано 60 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:45:51,660 [INFO] ✅ Собрано 91 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:45:53,101 [INFO] ✅ Собрано 132 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:45:53,628 [INFO] ✅ Собрано 68 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:45:54,571 [INFO] ✅ Собрано 44 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:45:55,059 [INFO] ✅ Собрано 67 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:45:55,435 [INFO] ✅ Собрано 63 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:45:55,872 [INFO] ✅ Собрано 91 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:45:56,134 [INFO] ✅ Собрано 31 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:45:56,596 [INFO] ✅ Собрано 6 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:45:56,827 [INFO] ✅ Собрано 8 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:45:57,145 [INFO] ✅ Собрано 13 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:45:57,552 [INFO] ✅ Собрано 12 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:45:57,847 [INFO] ✅ Собрано 4 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:45:57,849 [INFO]
# == Роль: Системный администратор (ID 113) ==
# 2025-08-25 12:45:58,372 [INFO] ✅ Собрано 84 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:45:58,854 [INFO] ✅ Собрано 81 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:45:59,354 [INFO] ✅ Собрано 87 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:46:00,724 [INFO] ✅ Собрано 155 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:46:01,142 [INFO] ✅ Собрано 64 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:46:05,034 [INFO] ✅ Собрано 370 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:46:09,520 [INFO] ✅ Собрано 434 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:46:14,332 [INFO] ✅ Собрано 485 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:46:22,819 [INFO] ✅ Собрано 775 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:46:25,994 [INFO] ✅ Собрано 360 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:46:27,566 [INFO] ✅ Собрано 188 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:46:29,982 [INFO] ✅ Собрано 258 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:46:31,218 [INFO] Долгая пауза 60 сек после 500 запросов...
# 2025-08-25 12:47:33,117 [INFO] ✅ Собрано 249 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:47:37,616 [INFO] ✅ Собрано 439 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:47:40,066 [INFO] ✅ Собрано 214 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:47:40,489 [INFO] ✅ Собрано 32 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:47:40,823 [INFO] ✅ Собрано 24 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:47:41,181 [INFO] ✅ Собрано 35 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:47:41,549 [INFO] ✅ Собрано 51 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:47:41,799 [INFO] ✅ Собрано 23 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:47:41,802 [INFO]
# == Роль: Системный аналитик (ID 148) ==
# 2025-08-25 12:47:42,152 [INFO] ✅ Собрано 14 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:47:42,490 [INFO] ✅ Собрано 13 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:47:42,808 [INFO] ✅ Собрано 18 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:47:43,175 [INFO] ✅ Собрано 26 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:47:43,584 [INFO] ✅ Собрано 9 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:47:43,979 [INFO] ✅ Собрано 60 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:47:44,441 [INFO] ✅ Собрано 91 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:47:44,961 [INFO] ✅ Собрано 91 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:47:46,371 [INFO] ✅ Собрано 157 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:47:46,766 [INFO] ✅ Собрано 69 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:47:48,105 [INFO] ✅ Собрано 111 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:47:49,428 [INFO] ✅ Собрано 158 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:47:50,845 [INFO] ✅ Собрано 187 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:47:53,163 [INFO] ✅ Собрано 210 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:47:54,344 [INFO] ✅ Собрано 101 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:47:54,810 [INFO] ✅ Собрано 12 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:47:55,090 [INFO] ✅ Собрано 16 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:47:55,660 [INFO] ✅ Собрано 21 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:47:55,993 [INFO] ✅ Собрано 30 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:47:56,215 [INFO] ✅ Собрано 14 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:47:56,219 [INFO]
# == Роль: Системный инженер (ID 114) ==
# 2025-08-25 12:47:56,651 [INFO] ✅ Собрано 15 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:47:56,915 [INFO] ✅ Собрано 16 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:47:57,303 [INFO] ✅ Собрано 15 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:47:57,675 [INFO] ✅ Собрано 26 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:47:57,901 [INFO] ✅ Собрано 10 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:47:58,439 [INFO] ✅ Собрано 68 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:47:58,918 [INFO] ✅ Собрано 81 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:47:59,451 [INFO] ✅ Собрано 85 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:48:01,023 [INFO] ✅ Собрано 144 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:48:01,406 [INFO] ✅ Собрано 50 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:48:01,788 [INFO] ✅ Собрано 52 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:48:02,300 [INFO] ✅ Собрано 58 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:48:02,773 [INFO] ✅ Собрано 72 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:48:03,260 [INFO] ✅ Собрано 94 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:48:03,639 [INFO] ✅ Собрано 49 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:48:03,878 [INFO] ✅ Собрано 5 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:48:04,288 [INFO] ✅ Собрано 9 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:48:04,624 [INFO] ✅ Собрано 9 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:48:04,929 [INFO] ✅ Собрано 12 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:48:05,186 [INFO] ✅ Собрано 5 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:48:05,187 [INFO]
# == Роль: Специалист по информационной безопасности (ID 116) ==
# 2025-08-25 12:48:05,890 [INFO] ✅ Собрано 50 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:48:06,455 [INFO] ✅ Собрано 70 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:48:06,999 [INFO] ✅ Собрано 68 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:48:07,557 [INFO] ✅ Собрано 82 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:48:07,865 [INFO] ✅ Собрано 24 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:48:10,630 [INFO] ✅ Собрано 262 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:48:14,025 [INFO] ✅ Собрано 314 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:48:18,016 [INFO] ✅ Собрано 343 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:48:24,044 [INFO] ✅ Собрано 503 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:48:26,128 [INFO] ✅ Собрано 159 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:48:27,877 [INFO] ✅ Собрано 170 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:48:30,717 [INFO] ✅ Собрано 267 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:48:33,563 [INFO] ✅ Собрано 271 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:48:37,063 [INFO] ✅ Собрано 355 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:48:38,509 [INFO] ✅ Собрано 144 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:48:39,018 [INFO] ✅ Собрано 25 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:48:39,380 [INFO] ✅ Собрано 28 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:48:39,628 [INFO] ✅ Собрано 23 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:48:40,085 [INFO] ✅ Собрано 42 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:48:40,307 [INFO] ✅ Собрано 14 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:48:40,312 [INFO]
# == Роль: Специалист технической поддержки (ID 121) ==
# 2025-08-25 12:48:44,797 [INFO] ✅ Собрано 422 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:48:50,017 [INFO] ✅ Собрано 478 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:48:55,796 [INFO] ✅ Собрано 580 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:49:06,227 [INFO] ✅ Собрано 909 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:49:10,377 [INFO] ✅ Собрано 421 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:49:14,020 [INFO] ✅ Собрано 395 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:49:18,697 [INFO] ✅ Собрано 496 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:49:25,431 [INFO] ✅ Собрано 629 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:49:35,111 [INFO] ✅ Собрано 990 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:49:41,643 [INFO] ✅ Собрано 601 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:49:42,298 [INFO] ✅ Собрано 68 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:49:43,002 [INFO] ✅ Собрано 85 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:49:44,433 [INFO] ✅ Собрано 125 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:49:46,080 [INFO] ✅ Собрано 181 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:49:46,589 [INFO] ✅ Собрано 98 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:49:46,963 [INFO] ✅ Собрано 6 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:49:47,306 [INFO] ✅ Собрано 6 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:49:47,571 [INFO] ✅ Собрано 8 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:49:47,870 [INFO] ✅ Собрано 9 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:49:48,203 [INFO] ✅ Собрано 3 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:49:48,205 [INFO]
# == Роль: Тестировщик (ID 124) ==
# 2025-08-25 12:49:48,657 [INFO] ✅ Собрано 17 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:49:48,906 [INFO] ✅ Собрано 25 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:49:49,298 [INFO] ✅ Собрано 28 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:49:50,038 [INFO] ✅ Собрано 60 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:49:50,301 [INFO] ✅ Собрано 20 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:49:51,757 [INFO] ✅ Собрано 172 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:49:53,094 [INFO] ✅ Собрано 142 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:49:54,243 [INFO] ✅ Собрано 174 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:49:56,648 [INFO] ✅ Собрано 225 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:49:57,954 [INFO] ✅ Собрано 106 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:49:58,504 [INFO] ✅ Собрано 95 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:49:58,951 [INFO] ✅ Собрано 96 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:00,163 [INFO] ✅ Собрано 126 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:01,811 [INFO] ✅ Собрано 186 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:02,225 [INFO] ✅ Собрано 75 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:02,457 [INFO] ✅ Собрано 23 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:50:02,828 [INFO] ✅ Собрано 20 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:03,217 [INFO] ✅ Собрано 18 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:03,627 [INFO] ✅ Собрано 33 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:04,051 [INFO] ✅ Собрано 9 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:04,052 [INFO]
# == Роль: Технический директор (CTO) (ID 125) ==
# 2025-08-25 12:50:04,305 [INFO] ✅ Собрано 3 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:50:04,740 [INFO] ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:50:04,978 [INFO] ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:50:05,275 [INFO] ✅ Собрано 3 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:50:05,606 [INFO] ✅ Собрано 0 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:50:05,994 [INFO] ✅ Собрано 5 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:50:06,330 [INFO] ✅ Собрано 16 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:50:06,784 [INFO] ✅ Собрано 27 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:50:07,163 [INFO] ✅ Собрано 34 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:50:07,415 [INFO] ✅ Собрано 15 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:50:07,854 [INFO] ✅ Собрано 55 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:50:08,313 [INFO] ✅ Собрано 54 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:08,880 [INFO] ✅ Собрано 85 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:09,655 [INFO] ✅ Собрано 88 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:10,029 [INFO] ✅ Собрано 48 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:10,305 [INFO] ✅ Собрано 23 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:50:10,795 [INFO] ✅ Собрано 48 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:11,148 [INFO] ✅ Собрано 36 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:11,552 [INFO] ✅ Собрано 61 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:11,914 [INFO] ✅ Собрано 34 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:11,915 [INFO]
# == Роль: Технический писатель (ID 126) ==
# 2025-08-25 12:50:12,170 [INFO] ✅ Собрано 5 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-26–2025-08-02
# 2025-08-25 12:50:12,480 [INFO] ✅ Собрано 7 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-08-02–2025-08-09
# 2025-08-25 12:50:12,931 [INFO] ✅ Собрано 7 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-08-09–2025-08-16
# 2025-08-25 12:50:13,125 [INFO] ✅ Собрано 8 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-08-16–2025-08-23
# 2025-08-25 12:50:13,500 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-08-23–2025-08-25
# 2025-08-25 12:50:14,015 [INFO] ✅ Собрано 31 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-26–2025-08-02
# 2025-08-25 12:50:14,439 [INFO] ✅ Собрано 90 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-08-02–2025-08-09
# 2025-08-25 12:50:15,033 [INFO] ✅ Собрано 50 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-08-09–2025-08-16
# 2025-08-25 12:50:15,482 [INFO] ✅ Собрано 83 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-08-16–2025-08-23
# 2025-08-25 12:50:15,925 [INFO] ✅ Собрано 33 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-08-23–2025-08-25
# 2025-08-25 12:50:16,344 [INFO] ✅ Собрано 14 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-26–2025-08-02
# 2025-08-25 12:50:16,667 [INFO] ✅ Собрано 25 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:17,071 [INFO] ✅ Собрано 28 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:17,474 [INFO] ✅ Собрано 51 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:17,746 [INFO] ✅ Собрано 16 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:18,049 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-26–2025-08-02
# 2025-08-25 12:50:18,330 [INFO] ✅ Собрано 1 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-08-02–2025-08-09
# 2025-08-25 12:50:18,637 [INFO] ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-08-09–2025-08-16
# 2025-08-25 12:50:19,008 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-08-16–2025-08-23
# 2025-08-25 12:50:19,354 [INFO] ✅ Собрано 1 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-08-23–2025-08-25
# 2025-08-25 12:50:23,543 [INFO]
# ✅ Все вакансии прошли валидацию. Reject-файл не создан.
# 2025-08-25 12:50:23,544 [INFO]
# 🚀 Всего собрано вакансий: 47709
# 2025-08-25 12:50:23,569 [INFO] 📦 Загружено уникальных id: 45310
# 2025-08-25 12:50:23,570 [INFO] ⏱ Время выполнения (hh_parser): 00:09:43.82 секунд

# %%
valid_df.info()

# %%
valid_df.head()
# Out:
#                load_datetime             professional_role         id  \
# 0 2025-08-23 21:39:22.792162  BI-аналитик, аналитик данных  123259817
# 1 2025-08-23 21:39:22.792257  BI-аналитик, аналитик данных  123363422
# 2 2025-08-23 21:39:22.792311  BI-аналитик, аналитик данных  123233941
# 3 2025-08-23 21:39:22.792351  BI-аналитик, аналитик данных  123418505
# 4 2025-08-23 21:39:22.792439  BI-аналитик, аналитик данных  123415001
#
#                                                 name        area area_id  \
# 0                            Младший аналитик данных      Москва       1
# 1       Intern Data Analyst / Стажер Аналитик данных      Москва       1
# 2                               Стажер Data-аналитик      Москва       1
# 3  Младший программист-аналитик (Junior Program A...  Ставрополь      84
# 4                  Аналитик развития DWH (Ярославль)   Ярославль     112
#
#                          employer accredited_it_employer  trusted_employer  \
# 0                   Topface Media                  False              True
# 1                           Okkam                  False              True
# 2                              T2                  False              True
# 3  Николенко Сергей Александрович                  False              True
# 4         Лига Цифровой Экономики                   True              True
#
#                published_at  ... archived                              url  \
# 0  2025-07-25T14:49:47+0300  ...    False  https://hh.ru/vacancy/123259817
# 1  2025-07-29T12:37:43+0300  ...    False  https://hh.ru/vacancy/123363422
# 2  2025-07-25T11:08:17+0300  ...    False  https://hh.ru/vacancy/123233941
# 3  2025-07-30T12:08:41+0300  ...    False  https://hh.ru/vacancy/123418505
# 4  2025-07-30T11:21:16+0300  ...    False  https://hh.ru/vacancy/123415001
#
#    salary_from salary_to  currency  salary_mode salary_frequency experience  \
# 0      40000.0   60000.0       RUR     За месяц             None  Нет опыта
# 1          NaN       NaN      None         None             None  Нет опыта
# 2          NaN       NaN      None         None             None  Нет опыта
# 3      30000.0   50000.0       RUR     За месяц             None  Нет опыта
# 4          NaN       NaN      None         None             None  Нет опыта
#
#            schedule           employment
# 0  Удаленная работа     Полная занятость
# 1       Полный день  Частичная занятость
# 2     Гибкий график  Частичная занятость
# 3  Удаленная работа     Полная занятость
# 4       Полный день     Полная занятость
#
# [5 rows x 22 columns]

# %%
# ============ Первичная загрузка key_skills ============
import asyncio
import aiohttp
import logging
import random
import time
from datetime import datetime
from collections import deque
import pandas as pd


# --- RateLimiter (ограничение по RPS)
class RateLimiter:
    def __init__(self, max_calls: int, period: float = 1.0):
        self.max_calls = max_calls
        self.period = period
        self.calls = deque()

    async def __aenter__(self):
        while len(self.calls) >= self.max_calls and time.monotonic() - self.calls[0] < self.period:
            await asyncio.sleep(self.period - (time.monotonic() - self.calls[0]))
        self.calls.append(time.monotonic())
        return self

    async def __aexit__(self, exc_type, exc, tb):
        pass


# --- Функция получения key_skills для одной вакансии с retry
async def fetch_keyskills(session, vacancy_id, limiter, sem, logger, max_retries=3):
    url = f"https://api.hh.ru/vacancies/{vacancy_id}"
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (X11; Ubuntu; Linux x86_64) AppleWebKit/537.36 "
            "(KHTML, like Gecko) Chrome/127.0 Safari/537.36"
        )
    }

    for attempt in range(1, max_retries + 1):
        async with sem:
            async with limiter:
                # небольшая случайная пауза для сглаживания нагрузки
                await asyncio.sleep(random.uniform(0.1, 0.5))
                try:
                    async with session.get(url, headers=headers) as resp:
                        if resp.status == 200:
                            data = await resp.json()
                            key_skills = data.get("key_skills", [])
                            if not key_skills:
                                return vacancy_id, ["не указано"]
                            return vacancy_id, [ks["name"] for ks in key_skills]

                        elif resp.status in (403, 429):
                            wait = 60 * attempt  # экспоненциальная пауза
                            logger.warning(
                                f"⚠️ Ошибка {resp.status} для вакансии {vacancy_id}, "
                                f"попытка {attempt}, жду {wait} сек"
                            )
                            await asyncio.sleep(wait)
                            continue

                        else:
                            logger.error(f"❌ Ошибка {resp.status} при получении вакансии {vacancy_id}")
                            return vacancy_id, None

                except Exception as e:
                    logger.error(f"❌ Исключение для {vacancy_id}: {e}")
                    await asyncio.sleep(5)

    # если все попытки неудачные
    return vacancy_id, None


# --- Основная функция первичной загрузки key_skills
async def collect_keyskills_primary(
    vacancy_ids, batch_size=2000, inner_batch=50, pause_hours=0.5, rps=2, concurrency=2, log_file=None
):
    # Логгер
    logger = logging.getLogger("keyskills_logger")
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    if log_file is None:
        log_file = f"keyskills_primary_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"
    fh = logging.FileHandler(log_file, mode="w", encoding="utf-8")
    formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
    fh.setFormatter(formatter)
    logger.addHandler(fh)

    logger.info("▶️ Старт первичной загрузки key_skills")
    
    results = []
    limiter = RateLimiter(rps)
    sem = asyncio.Semaphore(concurrency)

    async with aiohttp.ClientSession() as session:
        total = len(vacancy_ids)
        for i in range(0, total, batch_size):
            batch = vacancy_ids[i:i + batch_size]
            logger.info(f"🔹 Обработка батча {i // batch_size + 1}, вакансий: {len(batch)}")
            
            # --- обрабатываем batch по кускам inner_batch ---
            for j in range(0, len(batch), inner_batch):
                sub_batch = batch[j:j + inner_batch]
                tasks = [fetch_keyskills(session, vid, limiter, sem, logger) for vid in sub_batch]
                sub_results = await asyncio.gather(*tasks)
                results.extend([r for r in sub_results if r is not None])

                # пауза между подбатчами, чтобы не нагружать API
                await asyncio.sleep(random.uniform(1, 3))

            logger.info(f"✅ Завершен батч {i // batch_size + 1}/{(total - 1) // batch_size + 1}")
            print(f"✅ Завершен батч {i // batch_size + 1}/{(total - 1) // batch_size + 1}")

            if i + batch_size < total:
                logger.info(f"⏸ Пауза {pause_hours} ч перед следующим батчем...")
                print(f"⏸ Пауза {pause_hours} ч перед следующим батчем...")
                await asyncio.sleep(pause_hours * 3600)

    logger.info("🏁 Первичная загрузка key_skills завершена")
    print("🏁 Первичная загрузка key_skills завершена")

    # Преобразуем в DataFrame
    data = []
    for vacancy_id, skills in results:
        if skills is None:
            continue
        for skill in skills:
            data.append({"vacancy_id": vacancy_id, "key_skill": skill})

    df_keyskills = pd.DataFrame(data)
    return df_keyskills

# %%
# --- Запуск первичного сбора key_skills---
vacancy_ids = valid_df["id"].dropna().astype(str).tolist()

df_keyskills = await collect_keyskills_primary(
    vacancy_ids,
    batch_size=2000,  # крупный батч (разделится на inner_batch)
    inner_batch=50,   # внутри обрабатываем по 50 вакансий
    rps=3,            # не более 3 запросов/сек
    concurrency=2     # максимум 2 одновременно
)

df_keyskills.head()
# Out:
# 2025-08-25 14:47:34,707 [INFO] ▶️ Старт первичной загрузки key_skills
# 2025-08-25 14:47:34,707 [INFO] 🔹 Обработка батча 1, вакансий: 2000
# 🔹 Обработка батча 1, вакансий: 2000
# 2025-08-25 14:48:11,035 [WARNING] ⚠️ Ошибка 403 для вакансии 124418159, попытка 1, жду 60 сек
# 2025-08-25 14:48:11,069 [WARNING] ⚠️ Ошибка 403 для вакансии 120863837, попытка 1, жду 60 сек
# 2025-08-25 14:49:46,909 [WARNING] ⚠️ Ошибка 403 для вакансии 123616420, попытка 1, жду 60 сек
# 2025-08-25 14:49:47,245 [WARNING] ⚠️ Ошибка 403 для вакансии 123717542, попытка 1, жду 60 сек
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 # --- Запуск первичного сбора key_skills---
#       2 vacancy_ids = valid_df["id"].dropna().astype(str).tolist()
# ----> 4 df_keyskills = await collect_keyskills_primary(
#       5     vacancy_ids,
#       6     batch_size=2000,  # крупный батч (разделится на inner_batch)
#       7     inner_batch=50,   # внутри обрабатываем по 50 вакансий
#       8     rps=3,            # не более 3 запросов/сек
#       9     concurrency=2     # максимум 2 одновременно
#      10 )
#      12 df_keyskills.head()
#
# Cell In[8], line 107, in collect_keyskills_primary(vacancy_ids, batch_size, inner_batch, pause_hours, rps, concurrency, log_file)
#     105 sub_batch = batch[j:j + inner_batch]
#     106 tasks = [fetch_keyskills(session, vid, limiter, sem, logger) for vid in sub_batch]
# --> 107 sub_results = await asyncio.gather(*tasks)
#     108 results.extend([r for r in sub_results if r is not None])
#     110 # пауза между подбатчами, чтобы не нагружать API
#
# Cell In[8], line 59, in fetch_keyskills(session, vacancy_id, limiter, sem, logger, max_retries)
#      54     wait = 60 * attempt  # экспоненциальная пауза
#      55     logger.warning(
#      56         f"⚠️ Ошибка {resp.status} для вакансии {vacancy_id}, "
#      57         f"попытка {attempt}, жду {wait} сек"
#      58     )
# ---> 59     await asyncio.sleep(wait)
#      60     continue
#      62 else:
#
# File ~/anaconda3/envs/educational/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %%
# vacancy_ids = valid_df["id"].unique().tolist()
# results = await collect_keyskills_primary(vacancy_ids, batch_size=7500, pause_hours=1)
# key_skills_all = []
# for v in results:
#     if not v:
#         continue
#     if v.get("key_skills"):
#         for skill in v["key_skills"]:
#             key_skills_all.append({"vacancy_id": v["id"], "key_skill": skill["name"]})
#     else:
#         key_skills_all.append({"vacancy_id": v["id"], "key_skill": "не указано"})

# df_key_skills = pd.DataFrame(key_skills_all)

# %%
# Сбор key_skills - черновик

# async def extract_key_skills(raw_vacancies: list, session: aiohttp.ClientSession, rate_limiter, logger) -> pd.DataFrame:
#     all_key_skills = []
#     total = len(raw_vacancies)

#     for idx, vac in enumerate(raw_vacancies, 1):
#         vac_id = vac.get("id")
#         if not vac_id:
#             continue

#         url = f"https://api.hh.ru/vacancies/{vac_id}"

#         await rate_limiter.wait()

#         try:
#             async with session.get(url) as response:
#                 if response.status != 200:
#                     logger.warning(f"[{idx}/{total}] Не удалось получить key_skills для вакансии {vac_id}, статус {response.status}")
#                     all_key_skills.append({"vacancy_id": vac_id, "key_skill": "не указаны"})
#                     continue
#                 vacancy_detail = await response.json()
#         except Exception as e:
#             logger.warning(f"[{idx}/{total}] Ошибка при запросе key_skills для {vac_id}: {e}")
#             all_key_skills.append({"vacancy_id": vac_id, "key_skill": "не указаны"})
#             continue

#         key_skills = vacancy_detail.get("key_skills", [])
#         if not key_skills:
#             all_key_skills.append({"vacancy_id": vac_id, "key_skill": "не указаны"})
#         else:
#             for skill_entry in key_skills:
#                 skill = skill_entry.get("name", "").strip()
#                 all_key_skills.append({"vacancy_id": vac_id, "key_skill": skill})

#         if idx % 500 == 0 or idx == total:
#             logger.info(f"🔹 Обработано {idx}/{total} вакансий для key_skills")

#     return pd.DataFrame(all_key_skills)

# %%
# # Сбор вакансий и key_skills - черновик

# start = time.perf_counter()
# raw_vacancies = await collect_vacancies_async()
# df = extract_vacancy_data(raw_vacancies)

# # Валидация вакансий
# reference_data = await fetch_reference_data()
# valid_df, reject_df = validate_vacancies(df, reference_data)

# # Загрузка key_skills
# async with aiohttp.ClientSession(headers=header) as session:
#     df_key_skills = await extract_key_skills(raw_vacancies, session, limiter, logging)

# # Информация по результатам
# logging.info(f"\n🚀 Всего собрано вакансий: {len(raw_vacancies)}")
# logging.info(f"📦 Загружено уникальных id: {valid_df['id'].nunique()}")
# logging.info(f"🔑 Сформировано строк в key_skills: {len(df_key_skills)}")

# log_elapsed_time(start, "hh_parser + key_skills")
