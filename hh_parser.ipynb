# %%
import aiohttp
import asyncio
import pandas as pd
import random
import time
from datetime import datetime, timedelta, timezone

# === Настройки ===
header = {'User-Agent': 'HH-Data-Coll/v1.0 (contact 135861v@mail.ru)'}
area_id_russia = 113
per_page = 100
max_pages = 100
semaphore = asyncio.Semaphore(5)

# Опыт
experiences = ['noExperience', 'between1And3', 'between3And6', 'moreThan6']

# Период: последние 30 дней с шагом 7 дней
def get_date_ranges(days=30, step=7):
    today = datetime.now(timezone.utc).date()
    start_date = today - timedelta(days=days)
    ranges = []
    current = start_date
    while current < today:
        end = min(current + timedelta(days=step), today)
        ranges.append((current.isoformat(), end.isoformat()))
        current = end
    return ranges

# RateLimiter
class RateLimiter:
    def __init__(self, max_rps=3, long_pause_every=500, long_pause_duration=60):
        self.max_rps = max_rps
        self.long_pause_every = long_pause_every
        self.long_pause_duration = long_pause_duration
        self.last_request = None
        self.request_count = 0
        self.lock = asyncio.Lock()

    async def wait(self):
        async with self.lock:
            now = time.monotonic()
            if self.last_request is not None:
                elapsed = now - self.last_request
                delay = max(0, 1.0 / self.max_rps - elapsed)
                if delay > 0:
                    await asyncio.sleep(delay)
            self.last_request = time.monotonic()
            self.request_count += 1
            if self.request_count % self.long_pause_every == 0:
                print(f"Долгая пауза {self.long_pause_duration} сек после {self.request_count} запросов...")
                await asyncio.sleep(self.long_pause_duration)

limiter = RateLimiter()

# Получение IT-ролей
async def fetch_it_roles():
    url = 'https://api.hh.ru/professional_roles'
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get(url) as response:
            response.raise_for_status()
            data = await response.json()
            for cat in data['categories']:
                if int(cat['id']) == 11:
                    roles = [
                        {'id': int(role['id']), 'name': role['name']}
                        for role in cat['roles']
                        if int(role['id']) not in [12, 25, 34, 155]
                    ]
                    print(f'🔹 Найдено {len(roles)} IT-ролей')
                    return roles
            return []

# Загрузка одной страницы
async def fetch_page(session, params, page, desc):
    params['page'] = page
    await limiter.wait()
    try:
        async with semaphore:
            async with session.get('https://api.hh.ru/vacancies', params=params) as response:
                if response.status == 403:
                    print(f"🚫 Ошибка 403 на странице {page} — {desc}")
                    return None
                response.raise_for_status()
                return await response.json()
    except Exception as e:
        print(f"⚠️ Ошибка на странице {page} — {desc}: {e}")
        await asyncio.sleep(random.uniform(1.0, 2.0))
        return None

# Сбор вакансий по комбинации ролей, опыта и дат
async def fetch_vacancies(session, role_id, role_name, experience, date_from, date_to):
    desc = f"роль '{role_name}', опыт '{experience}', {date_from}–{date_to}"
    vacancies = []
    params = {
        'professional_role': role_id,
        'area': area_id_russia,
        'experience': experience,
        'date_from': date_from,
        'date_to': date_to,
        'per_page': per_page,
    }

    for page in range(max_pages):
        data = await fetch_page(session, params, page, desc)
        if data is None:
            break
        items = data.get('items', [])
        if not items:
            break
        vacancies.extend(items)
        if page >= data.get('pages', 0) - 1:
            break
        await asyncio.sleep(random.uniform(0.3, 0.6))

    print(f"✅ Собрано {len(vacancies)} вакансий — {desc}")
    return vacancies

# Основной сбор данных
async def collect_vacancies_async():
    all_vacancies = []
    date_ranges = get_date_ranges()
    roles = await fetch_it_roles()

    async with aiohttp.ClientSession(headers=header) as session:
        for role in roles:
            print(f"\n== Роль: {role['name']} (ID {role['id']}) ==")
            for exp in experiences:
                for date_from, date_to in date_ranges:
                    batch = await fetch_vacancies(session, role['id'], role['name'], exp, date_from, date_to)
                    all_vacancies.extend(batch)

    print(f"\n🚀 Всего собрано {len(all_vacancies)} вакансий")
    return all_vacancies

# Преобразование вакансий в DataFrame
def extract_vacancy_data(raw_vacancies):
    extracted = []
    for v in raw_vacancies:
        area_info = v.get('area', {})
        extracted.append({
            'id': v.get('id'),
            'name': v.get('name'),
            'area': area_info.get('name'),
            'area_id': area_info.get('id'),
            'employer': v.get('employer', {}).get('name'),
            'published_at': v.get('published_at'),
            'created_at': v.get('created_at'),
            'closed_at': v.get('closed_at'),
            'archived': v.get('archived'),
            'url': v.get('alternate_url'),
            'salary_from': v.get('salary', {}).get('from') if v.get('salary') else None,
            'salary_to': v.get('salary', {}).get('to') if v.get('salary') else None,
            'currency': v.get('salary', {}).get('currency') if v.get('salary') else None,
            'experience': v.get('experience', {}).get('name'),
            'schedule': v.get('schedule', {}).get('name'),
            'employment': v.get('employment', {}).get('name'),
        })
    return pd.DataFrame(extracted)

# %%
raw_vacancies = await collect_vacancies_async()
df = extract_vacancy_data(raw_vacancies)
# Out:
# 🔹 Найдено 21 IT-ролей
#
# == Роль: BI-аналитик, аналитик данных (ID 156) ==
# ✅ Собрано 15 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 33 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 21 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 61 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 35 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 96 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 123 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 157 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 199 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 177 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 69 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 79 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 101 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 120 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 123 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 3 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 8 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 10 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 18 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 11 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: DevOps-инженер (ID 160) ==
# ✅ Собрано 6 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 5 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 11 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 9 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 10 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 44 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 56 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 65 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 97 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 73 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 95 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 130 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 146 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 174 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 141 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 16 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 22 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 27 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 40 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 37 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Аналитик (ID 10) ==
# ✅ Собрано 101 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 44 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 87 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 119 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 105 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 297 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 342 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 387 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 582 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 595 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 166 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 198 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 263 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 355 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 326 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 23 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 15 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 33 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 31 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 16 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Бизнес-аналитик (ID 150) ==
# ✅ Собрано 10 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 21 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 19 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 30 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 30 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 92 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 122 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 131 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 206 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 185 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 96 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 101 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 113 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 157 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 142 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 20 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 18 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 11 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 18 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 9 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Дата-сайентист (ID 165) ==
# ✅ Собрано 7 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 3 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 10 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 12 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 9 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 26 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 31 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 37 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 43 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 42 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 42 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 67 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 53 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 100 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 88 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 13 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 15 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 12 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 18 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 6 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Директор по информационным технологиям (CIO) (ID 36) ==
# ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 4 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 10 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 3 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 14 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 16 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 26 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 25 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 23 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 9 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 8 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 14 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Менеджер продукта (ID 73) ==
# ✅ Собрано 12 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 13 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 20 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 38 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 48 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 114 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 128 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 160 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 247 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 325 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 114 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 144 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 196 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 254 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 266 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 15 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 31 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 41 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 54 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Программист, разработчик (ID 96) ==
# ✅ Собрано 135 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 149 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 188 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 237 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 233 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 663 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 758 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 921 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 1330 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 1317 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 788 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 971 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 988 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 1447 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 1584 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 138 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 170 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 146 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 255 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 282 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Продуктовый аналитик (ID 164) ==
# ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 0 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 25 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 30 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 36 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 48 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 61 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 35 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 27 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 41 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 52 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 39 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 5 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Руководитель группы разработки (ID 104) ==
# ✅ Собрано 3 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 3 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 0 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 16 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 21 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 15 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 40 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 39 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 62 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 109 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 87 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 124 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 148 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 51 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 60 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 45 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 85 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 86 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Руководитель отдела аналитики (ID 157) ==
# ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 1 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 3 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 5 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 12 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 22 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 30 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 27 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 35 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 39 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 54 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 5 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 16 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 11 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 25 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 13 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Руководитель проектов (ID 107) ==
# ✅ Собрано 21 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 52 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 45 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 91 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 81 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 288 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 317 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 407 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 582 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 689 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 311 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 355 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 446 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 663 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 572 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 74 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 69 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 84 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 105 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 123 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Сетевой инженер (ID 112) ==
# ✅ Собрано 19 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 12 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 27 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 35 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 31 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 61 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 68 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 73 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 98 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 115 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 35 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 57 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 73 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 68 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 82 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 7 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 8 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 7 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 9 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 20 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Системный администратор (ID 113) ==
# ✅ Собрано 82 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 91 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 117 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 131 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 156 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-13–2025-07-15
# Долгая пауза 60 сек после 500 запросов...
# ✅ Собрано 408 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 519 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 547 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 660 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 717 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 172 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 236 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 252 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 386 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 375 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 15 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 30 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 47 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 42 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 58 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Системный аналитик (ID 148) ==
# ✅ Собрано 16 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 18 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 14 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 25 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 20 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 105 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 98 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 109 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 124 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 111 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 127 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 146 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 141 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 224 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 208 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 14 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 15 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 9 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 25 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 22 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Системный инженер (ID 114) ==
# ✅ Собрано 12 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 15 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 24 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 39 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 38 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 53 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 81 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 101 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 140 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 130 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 49 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 70 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 71 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 87 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 106 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 4 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 10 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 6 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 9 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 6 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Специалист по информационной безопасности (ID 116) ==
# ✅ Собрано 51 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 90 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 100 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 90 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 67 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 287 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 324 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 348 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 393 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 371 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 203 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 212 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 247 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 340 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 269 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 19 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 22 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 39 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 22 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 36 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Специалист технической поддержки (ID 121) ==
# ✅ Собрано 409 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 455 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 616 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 842 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 1143 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 494 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 448 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 681 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 996 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 1041 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 80 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 90 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 129 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 171 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 172 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 7 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 9 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 4 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 8 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 9 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Тестировщик (ID 124) ==
# ✅ Собрано 30 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 30 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 38 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 52 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 58 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 117 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 156 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 209 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 175 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 191 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 89 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 111 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 130 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 172 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 190 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 14 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 20 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 24 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 25 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 24 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Технический директор (CTO) (ID 125) ==
# ✅ Собрано 0 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 1 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 5 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 28 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 26 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 15 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 33 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 27 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 48 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 43 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 69 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 91 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 102 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 22 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 23 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 37 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 61 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 59 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# == Роль: Технический писатель (ID 126) ==
# ✅ Собрано 9 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-15–2025-06-22
# ✅ Собрано 25 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-22–2025-06-29
# ✅ Собрано 9 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-29–2025-07-06
# ✅ Собрано 9 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-06–2025-07-13
# ✅ Собрано 12 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-13–2025-07-15
# ✅ Собрано 34 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-15–2025-06-22
# ✅ Собрано 37 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-22–2025-06-29
# ✅ Собрано 49 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-29–2025-07-06
# ✅ Собрано 80 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-06–2025-07-13
# ✅ Собрано 75 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-13–2025-07-15
# ✅ Собрано 15 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-15–2025-06-22
# ✅ Собрано 34 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-22–2025-06-29
# ✅ Собрано 30 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-29–2025-07-06
# ✅ Собрано 40 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-06–2025-07-13
# ✅ Собрано 34 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-13–2025-07-15
# ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-15–2025-06-22
# ✅ Собрано 3 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-22–2025-06-29
# ✅ Собрано 4 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-29–2025-07-06
# ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-06–2025-07-13
# ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-13–2025-07-15
#
# 🚀 Всего собрано 54116 вакансий

# %%
df.head()
# Out:
#           id                                      name              area  \
# 0  120752510                               BI-Аналитик           Саратов
# 1  120892345                           Аналитик данных  Набережные Челны
# 2  121680073         Младший аналитик данных КХД (DWH)            Москва
# 3  121658033                       Младший аналитик BI            Москва
# 4  119855847  Специалист (оператор Excel и баз данных)            Москва
#
#   area_id              employer              published_at  \
# 0      79        Банк ВТБ (ПАО)  2025-06-16T12:35:43+0300
# 1    1641                 NINEL  2025-06-20T16:17:48+0300
# 2       1              МСП Банк  2025-06-16T14:16:10+0300
# 3       1                 ANCOR  2025-06-16T10:26:39+0300
# 4       1  Правительство Москвы  2025-06-18T15:31:53+0300
#
#                  created_at closed_at  archived  \
# 0  2025-06-16T12:35:43+0300      None     False
# 1  2025-06-20T16:17:48+0300      None     False
# 2  2025-06-16T14:16:10+0300      None     False
# 3  2025-06-16T10:26:39+0300      None     False
# 4  2025-06-18T15:31:53+0300      None     False
#
#                                url  salary_from  salary_to currency  \
# 0  https://hh.ru/vacancy/120752510          NaN        NaN     None
# 1  https://hh.ru/vacancy/120892345      50000.0    80000.0      RUR
# 2  https://hh.ru/vacancy/121680073          NaN        NaN     None
# 3  https://hh.ru/vacancy/121658033          NaN        NaN     None
# 4  https://hh.ru/vacancy/119855847          NaN        NaN     None
#
#   experience          schedule        employment
# 0  Нет опыта  Удаленная работа  Полная занятость
# 1  Нет опыта       Полный день  Полная занятость
# 2  Нет опыта  Удаленная работа  Полная занятость
# 3  Нет опыта       Полный день  Полная занятость
# 4  Нет опыта       Полный день  Полная занятость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54116 entries, 0 to 54115
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            54116 non-null  object
#  1   name          54116 non-null  object
#  2   area          54116 non-null  object
#  3   area_id       54116 non-null  object
#  4   employer      54116 non-null  object
#  5   published_at  54116 non-null  object
#  6   created_at    54116 non-null  object
#  7   closed_at     0 non-null      object
#  8   archived      54116 non-null  bool
#  9   url           54116 non-null  object
#  10  salary_from   21533 non-null  float64
#  11  salary_to     13239 non-null  float64
#  12  currency      24578 non-null  object
#  13  experience    54116 non-null  object
#  14  schedule      54116 non-null  object
#  15  employment    54116 non-null  object
# dtypes: bool(1), float64(2), object(13)
# memory usage: 6.2+ MB
