# %%
import aiohttp
import asyncio
import pandas as pd
import random
import time
from datetime import datetime, timedelta, timezone
import logging

# %%
# === Настройки ===
header = {'User-Agent': 'HH-Data-Coll/v1.0 (contact 135861v@mail.ru)'}
area_id_russia = 113
per_page = 100
max_pages = 100
semaphore = asyncio.Semaphore(5)

# Опыт
experiences = ['noExperience', 'between1And3', 'between3And6', 'moreThan6']

# Настройки логгирования
log_filename = f"hh_parser_log_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",  
    handlers=[
        logging.FileHandler(log_filename, encoding="utf-8"), 
        logging.StreamHandler()
    ]
)

def log_elapsed_time(start, task="Code"):
    end = time.perf_counter()
    elapsed = end - start
    mins, secs = divmod(elapsed, 60)
    hrs, mins = divmod(mins, 60)
    logging.info(f"⏱ Время выполнения ({task}): {int(hrs):02d}:{int(mins):02d}:{secs:.2f} секунд")


# Период: последние 30 дней с шагом 7 дней
def get_date_ranges(days=30, step=7):
    today = datetime.now(timezone.utc).date()
    start_date = today - timedelta(days=days)
    ranges = []
    current = start_date
    while current < today:
        end = min(current + timedelta(days=step), today)
        ranges.append((current.isoformat(), end.isoformat()))
        current = end
    return ranges

# Загрузка справочников для валидации данных
async def fetch_reference_data():
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get('https://api.hh.ru/dictionaries') as resp:
            dict_data = await resp.json()

        async with session.get('https://api.hh.ru/areas') as resp:
            area_data = await resp.json()
            area_ids = set()

            def extract_area_ids(areas):
                for a in areas:
                    area_ids.add(str(a['id']))
                    if 'areas' in a and a['areas']:
                        extract_area_ids(a['areas'])

            extract_area_ids(area_data)

        return {
            'experience': {e['name'] for e in dict_data['experience']},
            'employment': {e['name'] for e in dict_data['employment']},
            'schedule': {e['name'] for e in dict_data['schedule']},
            'area_ids': area_ids
        }

# RateLimiter
class RateLimiter:
    def __init__(self, max_rps=3, long_pause_every=500, long_pause_duration=60):
        self.max_rps = max_rps
        self.long_pause_every = long_pause_every
        self.long_pause_duration = long_pause_duration
        self.last_request = None
        self.request_count = 0
        self.lock = asyncio.Lock()

    async def wait(self):
        async with self.lock:
            now = time.monotonic()
            if self.last_request is not None:
                elapsed = now - self.last_request
                delay = max(0, 1.0 / self.max_rps - elapsed)
                if delay > 0:
                    await asyncio.sleep(delay)
            self.last_request = time.monotonic()
            self.request_count += 1
            if self.request_count % self.long_pause_every == 0:
                logging.info(f"Долгая пауза {self.long_pause_duration} сек после {self.request_count} запросов...")
                await asyncio.sleep(self.long_pause_duration)

limiter = RateLimiter()

# %%
#=== Функции сбора вакансий ===
# Получение IT-ролей
async def fetch_it_roles():
    url = 'https://api.hh.ru/professional_roles'
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get(url) as response:
            response.raise_for_status()
            data = await response.json()
            for cat in data['categories']:
                if int(cat['id']) == 11:
                    roles = [
                        {'id': int(role['id']), 'name': role['name']}
                        for role in cat['roles']
                        if int(role['id']) not in [12, 25, 34, 155]
                    ]
                    logging.info(f'🔹 Найдено {len(roles)} IT-ролей')
                    return roles
            return []

# Загрузка одной страницы с повторными попытками
async def fetch_page(session, params, page, desc, max_retries=3):
    params['page'] = page
    for attempt in range(1, max_retries + 1):
        await limiter.wait()
        try:
            async with semaphore:
                async with session.get('https://api.hh.ru/vacancies', params=params) as response:
                    if response.status == 403:
                        logging.warning(f"🚫 Ошибка 403 на странице {page} — {desc} (попытка {attempt})")
                    elif response.status >= 400:
                        logging.warning(f"⚠️ Ошибка {response.status} на странице {page} — {desc} (попытка {attempt})")
                    response.raise_for_status()
                    return await response.json()
        except Exception as e:
            logging.warning(f"⚠️ Исключение при загрузке страницы {page} — {desc} (попытка {attempt}): {e}")
            await asyncio.sleep(random.uniform(1.0, 2.0))

    error_msg = f"❌ Ошибка: не удалось загрузить страницу {page} — {desc} после {max_retries} попыток. Остановка."
    logging.error(error_msg)
    raise RuntimeError(error_msg)

# Сбор вакансий по комбинации ролей, опыта и дат
async def fetch_vacancies(session, role_id, role_name, experience, date_from, date_to):
    desc = f"роль '{role_name}', опыт '{experience}', {date_from}–{date_to}"
    vacancies = []
    params = {
        'professional_role': role_id,
        'area': area_id_russia,
        'experience': experience,
        'date_from': date_from,
        'date_to': date_to,
        'per_page': per_page,
    }

    for page in range(max_pages):
        data = await fetch_page(session, params, page, desc)
        if data is None:
            break
        items = data.get('items', [])
        if not items:
            break
        vacancies.extend(items)
        if page >= data.get('pages', 0) - 1:
            break
        await asyncio.sleep(random.uniform(0.3, 0.6))

    logging.info(f"✅ Собрано {len(vacancies)} вакансий — {desc}")
    return vacancies

# Основной сбор данных
async def collect_vacancies_async():
    all_vacancies = []
    date_ranges = get_date_ranges()
    roles = await fetch_it_roles()

    try:
        async with aiohttp.ClientSession(headers=header) as session:
            for role in roles:
                logging.info(f"\n== Роль: {role['name']} (ID {role['id']}) ==")
                for exp in experiences:
                    for date_from, date_to in date_ranges:
                        batch = await fetch_vacancies(session, role['id'], role['name'], exp, date_from, date_to)
                        all_vacancies.extend(batch)

    except RuntimeError as critical_error:
        logging.critical(f"🚨 Парсинг прерван: {critical_error}")
        raise  

    # logging.info(f"\n🚀 Всего собрано {len(all_vacancies)} вакансий")
    return all_vacancies

# Преобразование вакансий в DataFrame
def extract_vacancy_data(raw_vacancies):
    extracted = []
    for v in raw_vacancies:
        area_info = v.get('area', {})
        extracted.append({
            'load_datetime': datetime.now(),
            'id': v.get('id'),
            'name': v.get('name'),
            'area': area_info.get('name'),
            'area_id': area_info.get('id'),
            'employer': v.get('employer', {}).get('name'),
            'published_at': v.get('published_at'),
            'created_at': v.get('created_at'),
            'closed_at': v.get('closed_at'),
            'archived': v.get('archived'),
            'url': v.get('alternate_url'),
            'salary_from': v.get('salary', {}).get('from') if v.get('salary') else None,
            'salary_to': v.get('salary', {}).get('to') if v.get('salary') else None,
            'currency': v.get('salary', {}).get('currency') if v.get('salary') else None,
            'experience': v.get('experience', {}).get('name'),
            'schedule': v.get('schedule', {}).get('name'),
            'employment': v.get('employment', {}).get('name'),
        })
    return pd.DataFrame(extracted)

# Валидация данных
def validate_vacancies(df: pd.DataFrame, dicts: dict):
    required_fields = ['id', 'name', 'area', 'area_id', 'published_at']
    errors = []

    def is_empty(val):
        return val is None or val == "" or (isinstance(val, list) and len(val) == 0)

    invalid_rows = []

    for i, row in df.iterrows():
        row_errors = []

        # Проверка обязательных полей на пустоту
        for field in required_fields:
            if field not in row or is_empty(row[field]):
                row_errors.append(f"Пустое обязательное поле '{field}'")

        # Проверка значений из справочников
        if 'experience' in row and row['experience'] not in dicts['experience'] and not is_empty(row['experience']):
            row_errors.append(f"Неизвестное experience: {row['experience']}")
        if 'employment' in row and row['employment'] not in dicts['employment'] and not is_empty(row['employment']):
            row_errors.append(f"Неизвестное employment: {row['employment']}")
        if 'schedule' in row and row['schedule'] not in dicts['schedule'] and not is_empty(row['schedule']):
            row_errors.append(f"Неизвестное schedule: {row['schedule']}")
        if 'area_id' in row and str(row['area_id']) not in dicts['area_ids'] and not is_empty(row['area_id']):
            row_errors.append(f"Неизвестный area_id: {row['area_id']}")

        if row_errors:
            errors.append((i, row_errors))
            invalid_rows.append(i)

    if errors:
        for i, errs in errors:
            logging.warning(f"Строка {i} отклонена: {', '.join(errs)}")

    reject_df = df.loc[invalid_rows].copy()
    valid_df = df.drop(index=invalid_rows).reset_index(drop=True)

    return valid_df.reset_index(drop=True), reject_df.reset_index(drop=True)

# %%
# Запуск сбора вакансий
start = time.perf_counter()

raw_vacancies = await collect_vacancies_async()
df = extract_vacancy_data(raw_vacancies)

reference_data = await fetch_reference_data()
valid_df, reject_df = validate_vacancies(df, reference_data)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
reject_filename = f"rejected_vacancies_{timestamp}_reject.parquet"
if not reject_df.empty:
    reject_df.to_csv(reject_filename, index=False)
    logging.info(f"\n🚫 {len(reject_df)} вакансий отклонено и сохранено в файл {reject_filename}")
else:
    logging.info("\n✅ Все вакансии прошли валидацию. Reject-файл не создан.")


logging.info(f"\n🚀 Всего собрано вакансий: {len(raw_vacancies)}")
logging.info(f"📦 Загружено уникальных id: {valid_df['id'].nunique()}")

log_elapsed_time(start, "hh_parser")
# Out:
# 2025-07-28 19:56:14,326 [INFO] 🔹 Найдено 21 IT-ролей
# 2025-07-28 19:56:14,327 [INFO]
# == Роль: BI-аналитик, аналитик данных (ID 156) ==
# 2025-07-28 19:56:14,707 [INFO] ✅ Собрано 12 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:56:15,130 [INFO] ✅ Собрано 40 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:56:15,552 [INFO] ✅ Собрано 37 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:56:15,962 [INFO] ✅ Собрано 41 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:56:16,226 [INFO] ✅ Собрано 15 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:56:16,913 [INFO] ✅ Собрано 97 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:56:18,410 [INFO] ✅ Собрано 116 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:56:19,917 [INFO] ✅ Собрано 132 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:56:22,244 [INFO] ✅ Собрано 251 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:56:23,190 [INFO] ✅ Собрано 127 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:56:23,751 [INFO] ✅ Собрано 69 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:56:24,111 [INFO] ✅ Собрано 69 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:56:25,346 [INFO] ✅ Собрано 109 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:56:26,784 [INFO] ✅ Собрано 149 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:56:27,143 [INFO] ✅ Собрано 83 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:56:27,351 [INFO] ✅ Собрано 9 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:56:27,674 [INFO] ✅ Собрано 12 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:56:28,041 [INFO] ✅ Собрано 6 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:56:28,347 [INFO] ✅ Собрано 13 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:56:28,690 [INFO] ✅ Собрано 9 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:56:28,694 [INFO]
# == Роль: DevOps-инженер (ID 160) ==
# 2025-07-28 19:56:29,042 [INFO] ✅ Собрано 9 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:56:29,336 [INFO] ✅ Собрано 6 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:56:29,705 [INFO] ✅ Собрано 14 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:56:30,037 [INFO] ✅ Собрано 13 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:56:30,333 [INFO] ✅ Собрано 3 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:56:30,825 [INFO] ✅ Собрано 49 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:56:31,303 [INFO] ✅ Собрано 59 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:56:31,809 [INFO] ✅ Собрано 55 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:56:32,155 [INFO] ✅ Собрано 86 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:56:32,417 [INFO] ✅ Собрано 53 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:56:33,609 [INFO] ✅ Собрано 104 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:56:34,887 [INFO] ✅ Собрано 122 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:56:36,182 [INFO] ✅ Собрано 123 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:56:37,920 [INFO] ✅ Собрано 179 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:56:38,877 [INFO] ✅ Собрано 116 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:56:39,273 [INFO] ✅ Собрано 17 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:56:39,590 [INFO] ✅ Собрано 19 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:56:39,971 [INFO] ✅ Собрано 27 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:56:40,350 [INFO] ✅ Собрано 37 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:56:40,588 [INFO] ✅ Собрано 27 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:56:40,588 [INFO]
# == Роль: Аналитик (ID 10) ==
# 2025-07-28 19:56:41,022 [INFO] ✅ Собрано 54 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:56:41,425 [INFO] ✅ Собрано 71 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:56:41,991 [INFO] ✅ Собрано 99 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:56:43,296 [INFO] ✅ Собрано 111 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:56:43,789 [INFO] ✅ Собрано 96 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:56:45,688 [INFO] ✅ Собрано 243 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:56:48,591 [INFO] ✅ Собрано 335 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:56:52,807 [INFO] ✅ Собрано 421 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:56:58,270 [INFO] ✅ Собрано 595 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:57:02,847 [INFO] ✅ Собрано 441 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:57:05,123 [INFO] ✅ Собрано 172 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:07,725 [INFO] ✅ Собрано 229 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:10,316 [INFO] ✅ Собрано 251 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:13,632 [INFO] ✅ Собрано 337 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:15,900 [INFO] ✅ Собрано 244 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:16,270 [INFO] ✅ Собрано 23 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:16,505 [INFO] ✅ Собрано 24 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:16,855 [INFO] ✅ Собрано 23 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:17,159 [INFO] ✅ Собрано 19 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:17,501 [INFO] ✅ Собрано 19 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:17,503 [INFO]
# == Роль: Бизнес-аналитик (ID 150) ==
# 2025-07-28 19:57:17,987 [INFO] ✅ Собрано 12 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:57:18,228 [INFO] ✅ Собрано 12 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:57:18,534 [INFO] ✅ Собрано 8 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:57:18,991 [INFO] ✅ Собрано 28 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:57:19,323 [INFO] ✅ Собрано 31 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:57:19,898 [INFO] ✅ Собрано 97 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:57:20,988 [INFO] ✅ Собрано 125 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:57:22,381 [INFO] ✅ Собрано 145 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:57:23,725 [INFO] ✅ Собрано 199 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:57:24,840 [INFO] ✅ Собрано 121 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:57:25,333 [INFO] ✅ Собрано 81 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:26,569 [INFO] ✅ Собрано 103 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:27,960 [INFO] ✅ Собрано 137 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:29,454 [INFO] ✅ Собрано 169 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:29,823 [INFO] ✅ Собрано 77 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:30,050 [INFO] ✅ Собрано 11 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:30,399 [INFO] ✅ Собрано 10 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:30,721 [INFO] ✅ Собрано 14 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:31,094 [INFO] ✅ Собрано 22 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:31,364 [INFO] ✅ Собрано 8 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:31,366 [INFO]
# == Роль: Дата-сайентист (ID 165) ==
# 2025-07-28 19:57:31,672 [INFO] ✅ Собрано 3 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:57:32,090 [INFO] ✅ Собрано 6 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:57:32,369 [INFO] ✅ Собрано 8 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:57:32,683 [INFO] ✅ Собрано 5 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:57:33,034 [INFO] ✅ Собрано 8 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:57:33,496 [INFO] ✅ Собрано 29 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:57:33,840 [INFO] ✅ Собрано 27 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:57:34,151 [INFO] ✅ Собрано 37 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:57:34,539 [INFO] ✅ Собрано 55 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:57:34,794 [INFO] ✅ Собрано 28 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:57:35,220 [INFO] ✅ Собрано 37 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:35,639 [INFO] ✅ Собрано 72 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:36,044 [INFO] ✅ Собрано 89 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:36,862 [INFO] ✅ Собрано 73 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:37,216 [INFO] ✅ Собрано 69 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:37,503 [INFO] ✅ Собрано 7 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:37,784 [INFO] ✅ Собрано 15 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:38,095 [INFO] ✅ Собрано 10 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:38,437 [INFO] ✅ Собрано 18 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:38,757 [INFO] ✅ Собрано 9 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:38,759 [INFO]
# == Роль: Директор по информационным технологиям (CIO) (ID 36) ==
# 2025-07-28 19:57:39,048 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:57:39,379 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:57:39,727 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:57:40,054 [INFO] ✅ Собрано 2 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:57:40,387 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:57:40,902 [INFO] ✅ Собрано 9 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:57:41,069 [INFO] ✅ Собрано 3 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:57:41,425 [INFO] ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:57:41,782 [INFO] ✅ Собрано 11 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:57:42,076 [INFO] ✅ Собрано 3 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:57:42,593 [INFO] ✅ Собрано 20 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:42,807 [INFO] ✅ Собрано 18 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:43,194 [INFO] ✅ Собрано 21 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:43,528 [INFO] ✅ Собрано 26 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:43,832 [INFO] ✅ Собрано 15 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:44,149 [INFO] ✅ Собрано 8 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:44,448 [INFO] ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:44,819 [INFO] ✅ Собрано 13 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:57:45,191 [INFO] ✅ Собрано 16 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:57:45,492 [INFO] ✅ Собрано 3 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:57:45,494 [INFO]
# == Роль: Менеджер продукта (ID 73) ==
# 2025-07-28 19:57:45,866 [INFO] ✅ Собрано 11 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:57:46,248 [INFO] ✅ Собрано 20 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:57:46,633 [INFO] ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:57:46,974 [INFO] ✅ Собрано 45 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:57:47,286 [INFO] ✅ Собрано 45 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:57:47,728 [INFO] ✅ Собрано 88 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:57:49,114 [INFO] ✅ Собрано 135 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:57:50,468 [INFO] ✅ Собрано 176 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:57:52,650 [INFO] ✅ Собрано 281 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:57:54,817 [INFO] ✅ Собрано 230 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 19:57:56,387 [INFO] ✅ Собрано 140 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 19:57:57,800 [INFO] ✅ Собрано 151 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 19:57:59,045 [INFO] ✅ Собрано 172 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 19:58:01,637 [INFO] ✅ Собрано 261 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 19:58:03,140 [INFO] ✅ Собрано 180 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 19:58:03,354 [INFO] ✅ Собрано 22 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 19:58:03,732 [INFO] ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 19:58:04,105 [INFO] ✅ Собрано 33 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 19:58:04,473 [INFO] ✅ Собрано 50 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 19:58:04,821 [INFO] ✅ Собрано 31 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 19:58:04,822 [INFO]
# == Роль: Программист, разработчик (ID 96) ==
# 2025-07-28 19:58:06,133 [INFO] ✅ Собрано 126 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 19:58:07,587 [INFO] ✅ Собрано 135 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 19:58:08,807 [INFO] ✅ Собрано 188 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 19:58:10,047 [WARNING] 🚫 Ошибка 403 на странице 1 — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-19–2025-07-26 (попытка 1)
# 2025-07-28 19:58:10,048 [WARNING] ⚠️ Исключение при загрузке страницы 1 — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-19–2025-07-26 (попытка 1): 403, message='Forbidden', url='https://api.hh.ru/vacancies?professional_role=96&area=113&experience=noExperience&date_from=2025-07-19&date_to=2025-07-26&per_page=100&page=1'
# 2025-07-28 19:58:12,570 [INFO] ✅ Собрано 220 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 19:58:13,989 [INFO] ✅ Собрано 182 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 19:58:20,502 [INFO] ✅ Собрано 640 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 19:58:27,816 [INFO] ✅ Собрано 782 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 19:58:29,708 [INFO] Долгая пауза 60 сек после 1000 запросов...
# 2025-07-28 19:59:36,340 [INFO] ✅ Собрано 896 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 19:59:48,818 [INFO] ✅ Собрано 1273 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 19:59:58,298 [INFO] ✅ Собрано 984 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:00:04,955 [INFO] ✅ Собрано 663 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:00:13,414 [INFO] ✅ Собрано 859 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:00:24,185 [INFO] ✅ Собрано 1081 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:00:38,264 [INFO] ✅ Собрано 1485 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:00:50,341 [INFO] ✅ Собрано 1223 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:00:51,548 [INFO] ✅ Собрано 103 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:00:53,011 [INFO] ✅ Собрано 165 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:00:54,745 [INFO] ✅ Собрано 186 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:00:57,375 [INFO] ✅ Собрано 281 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:00:59,552 [INFO] ✅ Собрано 221 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:00:59,554 [INFO]
# == Роль: Продуктовый аналитик (ID 164) ==
# 2025-07-28 20:00:59,856 [INFO] ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:01:00,384 [INFO] ✅ Собрано 3 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:01:00,622 [INFO] ✅ Собрано 8 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:01:00,945 [INFO] ✅ Собрано 5 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:01:01,502 [INFO] ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:01:01,788 [INFO] ✅ Собрано 26 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:01:02,094 [INFO] ✅ Собрано 25 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:01:02,577 [INFO] ✅ Собрано 53 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:01:02,905 [INFO] ✅ Собрано 40 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:01:03,269 [INFO] ✅ Собрано 34 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:01:03,562 [INFO] ✅ Собрано 26 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:03,901 [INFO] ✅ Собрано 33 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:04,217 [INFO] ✅ Собрано 29 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:04,705 [INFO] ✅ Собрано 49 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:05,013 [INFO] ✅ Собрано 38 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:05,214 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:05,591 [INFO] ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:06,052 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:06,354 [INFO] ✅ Собрано 5 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:06,585 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:06,587 [INFO]
# == Роль: Руководитель группы разработки (ID 104) ==
# 2025-07-28 20:01:06,900 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:01:07,217 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:01:07,631 [INFO] ✅ Собрано 6 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:01:07,910 [INFO] ✅ Собрано 3 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:01:08,235 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:01:08,617 [INFO] ✅ Собрано 13 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:01:09,022 [INFO] ✅ Собрано 22 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:01:09,349 [INFO] ✅ Собрано 29 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:01:09,719 [INFO] ✅ Собрано 35 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:01:10,001 [INFO] ✅ Собрано 21 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:01:10,444 [INFO] ✅ Собрано 60 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:10,853 [INFO] ✅ Собрано 78 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:11,468 [INFO] ✅ Собрано 99 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:12,871 [INFO] ✅ Собрано 143 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:14,143 [INFO] ✅ Собрано 106 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:14,746 [INFO] ✅ Собрано 36 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:15,089 [INFO] ✅ Собрано 49 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:15,558 [INFO] ✅ Собрано 67 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:16,447 [INFO] ✅ Собрано 76 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:16,854 [INFO] ✅ Собрано 55 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:16,856 [INFO]
# == Роль: Руководитель отдела аналитики (ID 157) ==
# 2025-07-28 20:01:17,005 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:01:17,371 [INFO] ✅ Собрано 3 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:01:17,695 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:01:18,055 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:01:18,349 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:01:18,717 [INFO] ✅ Собрано 8 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:01:19,081 [INFO] ✅ Собрано 13 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:01:19,465 [INFO] ✅ Собрано 16 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:01:19,856 [INFO] ✅ Собрано 16 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:01:20,080 [INFO] ✅ Собрано 9 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:01:20,518 [INFO] ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:20,846 [INFO] ✅ Собрано 27 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:21,253 [INFO] ✅ Собрано 48 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:21,657 [INFO] ✅ Собрано 49 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:22,054 [INFO] ✅ Собрано 37 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:22,249 [INFO] ✅ Собрано 7 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:22,608 [INFO] ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:22,946 [INFO] ✅ Собрано 10 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:01:23,325 [INFO] ✅ Собрано 20 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:01:23,589 [INFO] ✅ Собрано 8 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:01:23,591 [INFO]
# == Роль: Руководитель проектов (ID 107) ==
# 2025-07-28 20:01:24,012 [INFO] ✅ Собрано 30 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:01:24,455 [INFO] ✅ Собрано 55 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:01:24,801 [INFO] ✅ Собрано 46 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:01:25,223 [INFO] ✅ Собрано 74 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:01:25,536 [INFO] ✅ Собрано 56 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:01:28,883 [INFO] ✅ Собрано 304 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:01:31,376 [INFO] ✅ Собрано 285 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:01:36,105 [INFO] ✅ Собрано 443 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:01:42,465 [INFO] ✅ Собрано 624 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:01:47,750 [INFO] ✅ Собрано 536 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:01:50,903 [INFO] ✅ Собрано 313 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:01:54,703 [INFO] ✅ Собрано 403 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:01:58,193 [INFO] ✅ Собрано 398 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:02:04,437 [INFO] ✅ Собрано 646 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:02:08,401 [INFO] ✅ Собрано 452 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:02:08,778 [INFO] ✅ Собрано 66 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:02:09,222 [INFO] ✅ Собрано 62 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:02:09,647 [INFO] ✅ Собрано 80 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:02:10,855 [INFO] ✅ Собрано 126 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:02:11,390 [INFO] ✅ Собрано 93 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:02:11,390 [INFO]
# == Роль: Сетевой инженер (ID 112) ==
# 2025-07-28 20:02:11,653 [INFO] ✅ Собрано 15 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:02:12,037 [INFO] ✅ Собрано 22 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:02:12,351 [INFO] ✅ Собрано 21 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:02:12,687 [INFO] ✅ Собрано 31 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:02:13,259 [INFO] ✅ Собрано 17 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:02:13,670 [INFO] ✅ Собрано 46 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:02:14,070 [INFO] ✅ Собрано 55 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:02:14,511 [INFO] ✅ Собрано 84 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:02:15,524 [INFO] ✅ Собрано 122 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:02:16,006 [INFO] ✅ Собрано 86 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:02:16,311 [INFO] ✅ Собрано 37 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:02:16,753 [INFO] ✅ Собрано 44 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:02:17,119 [INFO] ✅ Собрано 62 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:02:17,512 [INFO] ✅ Собрано 79 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:02:17,857 [INFO] ✅ Собрано 69 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:02:18,039 [INFO] ✅ Собрано 6 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:02:18,377 [INFO] ✅ Собрано 5 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:02:18,735 [INFO] ✅ Собрано 20 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:02:19,093 [INFO] ✅ Собрано 8 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:02:19,372 [INFO] ✅ Собрано 7 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:02:19,374 [INFO]
# == Роль: Системный администратор (ID 113) ==
# 2025-07-28 20:02:20,033 [INFO] ✅ Собрано 77 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:02:20,404 [INFO] ✅ Собрано 69 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:02:21,545 [INFO] ✅ Собрано 108 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:02:23,115 [INFO] ✅ Собрано 143 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:02:24,347 [INFO] ✅ Собрано 110 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:02:27,680 [INFO] ✅ Собрано 368 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:02:31,900 [INFO] ✅ Собрано 378 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:02:36,392 [INFO] ✅ Собрано 481 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:02:43,501 [INFO] ✅ Собрано 743 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:02:48,394 [INFO] ✅ Собрано 548 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:02:49,702 [INFO] ✅ Собрано 174 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:02:52,227 [INFO] ✅ Собрано 240 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:02:54,641 [INFO] ✅ Собрано 258 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:02:58,294 [INFO] ✅ Собрано 385 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:00,609 [INFO] ✅ Собрано 290 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:00,909 [INFO] ✅ Собрано 34 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:01,186 [INFO] ✅ Собрано 21 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:01,620 [INFO] ✅ Собрано 36 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:01,984 [INFO] ✅ Собрано 39 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:02,324 [INFO] ✅ Собрано 44 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:02,327 [INFO]
# == Роль: Системный аналитик (ID 148) ==
# 2025-07-28 20:03:02,542 [INFO] ✅ Собрано 9 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:03:02,970 [INFO] ✅ Собрано 14 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:03:03,215 [INFO] ✅ Собрано 23 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:03:03,602 [INFO] ✅ Собрано 36 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:03:03,861 [INFO] ✅ Собрано 20 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:03:04,391 [INFO] ✅ Собрано 72 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:03:04,757 [INFO] ✅ Собрано 84 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:03:06,398 [INFO] ✅ Собрано 111 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:03:07,863 [INFO] ✅ Собрано 149 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:03:08,218 [INFO] ✅ Собрано 99 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:03:09,398 [INFO] ✅ Собрано 102 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:10,849 [INFO] ✅ Собрано 146 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:13,023 [INFO] ✅ Собрано 202 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:15,375 [INFO] ✅ Собрано 209 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:16,545 [INFO] ✅ Собрано 119 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:16,813 [INFO] ✅ Собрано 6 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:17,161 [INFO] ✅ Собрано 15 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:17,536 [INFO] ✅ Собрано 18 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:17,897 [INFO] ✅ Собрано 26 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:18,212 [INFO] ✅ Собрано 21 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:18,215 [INFO]
# == Роль: Системный инженер (ID 114) ==
# 2025-07-28 20:03:18,539 [INFO] ✅ Собрано 16 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:03:18,945 [INFO] ✅ Собрано 27 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:03:19,220 [INFO] ✅ Собрано 18 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:03:19,557 [INFO] ✅ Собрано 28 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:03:19,911 [INFO] ✅ Собрано 18 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:03:20,426 [INFO] ✅ Собрано 58 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:03:20,849 [INFO] ✅ Собрано 95 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:03:21,445 [INFO] ✅ Собрано 94 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:03:22,568 [INFO] ✅ Собрано 129 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:03:23,649 [INFO] ✅ Собрано 102 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:03:24,224 [INFO] ✅ Собрано 44 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:24,676 [INFO] ✅ Собрано 52 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:25,206 [INFO] ✅ Собрано 78 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:25,671 [INFO] ✅ Собрано 86 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:26,160 [INFO] ✅ Собрано 71 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:26,452 [INFO] ✅ Собрано 4 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:26,725 [INFO] ✅ Собрано 9 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:27,386 [INFO] ✅ Собрано 10 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:27,610 [INFO] ✅ Собрано 9 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:27,953 [INFO] ✅ Собрано 6 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:27,955 [INFO]
# == Роль: Специалист по информационной безопасности (ID 116) ==
# 2025-07-28 20:03:28,617 [INFO] ✅ Собрано 74 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:03:29,078 [INFO] ✅ Собрано 63 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:03:29,516 [INFO] ✅ Собрано 63 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:03:30,012 [INFO] ✅ Собрано 94 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:03:30,415 [INFO] ✅ Собрано 46 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:03:33,252 [INFO] ✅ Собрано 258 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:03:36,092 [INFO] ✅ Собрано 266 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:03:39,665 [INFO] ✅ Собрано 372 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:03:43,667 [INFO] ✅ Собрано 486 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:03:45,719 [INFO] ✅ Собрано 258 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:03:47,052 [INFO] ✅ Собрано 174 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:49,895 [INFO] ✅ Собрано 230 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:52,713 [INFO] ✅ Собрано 277 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:56,129 [INFO] ✅ Собрано 316 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:58,023 [INFO] ✅ Собрано 181 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:58,434 [INFO] ✅ Собрано 31 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:03:58,636 [INFO] ✅ Собрано 12 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:03:59,023 [INFO] ✅ Собрано 21 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:03:59,463 [INFO] ✅ Собрано 35 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:03:59,808 [INFO] ✅ Собрано 25 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:03:59,812 [INFO]
# == Роль: Специалист технической поддержки (ID 121) ==
# 2025-07-28 20:04:04,063 [INFO] ✅ Собрано 448 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:04:07,970 [INFO] ✅ Собрано 419 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:04:15,557 [INFO] ✅ Собрано 705 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:04:23,827 [INFO] ✅ Собрано 805 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:04:30,775 [INFO] ✅ Собрано 629 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:04:36,194 [INFO] ✅ Собрано 420 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:04:40,869 [INFO] ✅ Собрано 497 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:04:47,628 [INFO] ✅ Собрано 618 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:04:57,247 [INFO] ✅ Собрано 1026 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:05:04,448 [INFO] ✅ Собрано 754 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:05:05,024 [INFO] ✅ Собрано 83 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:05:06,127 [INFO] ✅ Собрано 102 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:05:07,623 [INFO] ✅ Собрано 117 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:05:08,896 [INFO] ✅ Собрано 161 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:05:10,308 [INFO] ✅ Собрано 137 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:05:10,481 [INFO] ✅ Собрано 1 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:05:10,852 [INFO] ✅ Собрано 6 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:05:11,211 [INFO] ✅ Собрано 13 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:05:11,528 [INFO] ✅ Собрано 12 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:05:11,824 [INFO] ✅ Собрано 5 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:05:11,826 [INFO]
# == Роль: Тестировщик (ID 124) ==
# 2025-07-28 20:05:12,274 [INFO] ✅ Собрано 25 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:05:12,563 [INFO] ✅ Собрано 29 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:05:13,004 [INFO] ✅ Собрано 41 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:05:13,465 [INFO] ✅ Собрано 87 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:05:13,765 [INFO] ✅ Собрано 39 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:05:14,943 [INFO] ✅ Собрано 160 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:05:15,625 [INFO] ✅ Собрано 100 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:05:17,063 [INFO] ✅ Собрано 179 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:05:19,222 [INFO] ✅ Собрано 213 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:05:20,558 [INFO] ✅ Собрано 148 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:05:21,096 [INFO] ✅ Собрано 95 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:05:22,291 [INFO] ✅ Собрано 112 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:05:23,846 [INFO] ✅ Собрано 163 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:05:25,403 [INFO] ✅ Собрано 189 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:05:26,761 [INFO] ✅ Собрано 114 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:05:27,134 [INFO] ✅ Собрано 20 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:05:27,479 [INFO] ✅ Собрано 19 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:05:27,771 [INFO] ✅ Собрано 14 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:05:27,870 [INFO] Долгая пауза 60 сек после 1500 запросов...
# 2025-07-28 20:06:28,448 [INFO] ✅ Собрано 29 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:06:28,743 [INFO] ✅ Собрано 31 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:06:28,744 [INFO]
# == Роль: Технический директор (CTO) (ID 125) ==
# 2025-07-28 20:06:28,968 [INFO] ✅ Собрано 1 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:06:29,323 [INFO] ✅ Собрано 1 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:06:29,647 [INFO] ✅ Собрано 3 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:06:29,976 [INFO] ✅ Собрано 3 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:06:30,285 [INFO] ✅ Собрано 0 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:06:30,683 [INFO] ✅ Собрано 12 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:06:31,078 [INFO] ✅ Собрано 19 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:06:31,367 [INFO] ✅ Собрано 24 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:06:31,736 [INFO] ✅ Собрано 35 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:06:32,023 [INFO] ✅ Собрано 21 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:06:32,724 [INFO] ✅ Собрано 52 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:06:33,143 [INFO] ✅ Собрано 53 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:06:33,652 [INFO] ✅ Собрано 83 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:06:34,128 [INFO] ✅ Собрано 75 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:06:34,482 [INFO] ✅ Собрано 65 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:06:34,701 [INFO] ✅ Собрано 23 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:06:35,199 [INFO] ✅ Собрано 31 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:06:35,622 [INFO] ✅ Собрано 42 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:06:36,108 [INFO] ✅ Собрано 61 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:06:36,479 [INFO] ✅ Собрано 54 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:06:36,482 [INFO]
# == Роль: Технический писатель (ID 126) ==
# 2025-07-28 20:06:36,694 [INFO] ✅ Собрано 6 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-28–2025-07-05
# 2025-07-28 20:06:37,043 [INFO] ✅ Собрано 4 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-05–2025-07-12
# 2025-07-28 20:06:37,365 [INFO] ✅ Собрано 8 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-12–2025-07-19
# 2025-07-28 20:06:37,675 [INFO] ✅ Собрано 3 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-19–2025-07-26
# 2025-07-28 20:06:38,052 [INFO] ✅ Собрано 8 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-26–2025-07-28
# 2025-07-28 20:06:38,507 [INFO] ✅ Собрано 28 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-28–2025-07-05
# 2025-07-28 20:06:38,913 [INFO] ✅ Собрано 51 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-05–2025-07-12
# 2025-07-28 20:06:39,330 [INFO] ✅ Собрано 47 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-12–2025-07-19
# 2025-07-28 20:06:39,716 [INFO] ✅ Собрано 63 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-19–2025-07-26
# 2025-07-28 20:06:40,140 [INFO] ✅ Собрано 64 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-26–2025-07-28
# 2025-07-28 20:06:40,351 [INFO] ✅ Собрано 16 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-28–2025-07-05
# 2025-07-28 20:06:40,754 [INFO] ✅ Собрано 28 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-05–2025-07-12
# 2025-07-28 20:06:41,085 [INFO] ✅ Собрано 20 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-12–2025-07-19
# 2025-07-28 20:06:41,498 [INFO] ✅ Собрано 44 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-19–2025-07-26
# 2025-07-28 20:06:41,854 [INFO] ✅ Собрано 38 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-26–2025-07-28
# 2025-07-28 20:06:42,039 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-28–2025-07-05
# 2025-07-28 20:06:42,340 [INFO] ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-05–2025-07-12
# 2025-07-28 20:06:42,720 [INFO] ✅ Собрано 1 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-12–2025-07-19
# 2025-07-28 20:06:43,046 [INFO] ✅ Собрано 3 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-19–2025-07-26
# 2025-07-28 20:06:43,389 [INFO] ✅ Собрано 3 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-26–2025-07-28
# 2025-07-28 20:06:48,005 [INFO]
# ✅ Все вакансии прошли валидацию. Reject-файл не создан.
# 2025-07-28 20:06:48,006 [INFO]
# 🚀 Всего собрано вакансий: 49969
# 2025-07-28 20:06:48,037 [INFO] 📦 Загружено уникальных id: 47655
# 2025-07-28 20:06:48,038 [INFO] ⏱ Время выполнения (hh_parser): 00:10:34.01 секунд

# %%
valid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49969 entries, 0 to 49968
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   load_datetime  49969 non-null  datetime64[ns]
#  1   id             49969 non-null  object
#  2   name           49969 non-null  object
#  3   area           49969 non-null  object
#  4   area_id        49969 non-null  object
#  5   employer       49969 non-null  object
#  6   published_at   49969 non-null  object
#  7   created_at     49969 non-null  object
#  8   closed_at      0 non-null      object
#  9   archived       49969 non-null  bool
#  10  url            49969 non-null  object
#  11  salary_from    19515 non-null  float64
#  12  salary_to      11958 non-null  float64
#  13  currency       22193 non-null  object
#  14  experience     49969 non-null  object
#  15  schedule       49969 non-null  object
#  16  employment     49969 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(2), object(13)
# memory usage: 6.1+ MB

# %%
valid_df.head()
# Out:
#                load_datetime         id  \
# 0 2025-07-28 20:06:43.536101  122307065
# 1 2025-07-28 20:06:43.536115  122301031
# 2 2025-07-28 20:06:43.536119  121374239
# 3 2025-07-28 20:06:43.536123  122249561
# 4 2025-07-28 20:06:43.536127  122425111
#
#                                                 name      area area_id  \
# 0                                      Data Engineer  Оренбург      70
# 1                          Стажер системный аналитик    Москва       1
# 2                           Аналитик данных (Junior)    Москва       1
# 3                                    Аналитик данных    Москва       1
# 4  Ассистент по работе с данными (Ассистент анали...    Москва       1
#
#                                             employer  \
# 0  Министерство цифрового развития и связи Оренбу...
# 1                                         СберМобайл
# 2                                     Банк ВТБ (ПАО)
# 3                              Сыктывкар Тиссью Груп
# 4  Группа компаний «Group4Media», Управляющая ком...
#
#                published_at                created_at closed_at  archived  \
# 0  2025-07-02T13:43:25+0300  2025-07-02T13:43:25+0300      None     False
# 1  2025-07-02T11:55:06+0300  2025-07-02T11:55:06+0300      None     False
# 2  2025-07-03T14:13:24+0300  2025-07-03T14:13:24+0300      None     False
# 3  2025-07-01T12:39:43+0300  2025-07-01T12:39:43+0300      None     False
# 4  2025-07-04T16:02:08+0300  2025-07-04T16:02:08+0300      None     False
#
#                                url  salary_from  salary_to currency  \
# 0  https://hh.ru/vacancy/122307065      71000.0        NaN      RUR
# 1  https://hh.ru/vacancy/122301031          NaN        NaN     None
# 2  https://hh.ru/vacancy/121374239          NaN        NaN     None
# 3  https://hh.ru/vacancy/122249561     100000.0        NaN      RUR
# 4  https://hh.ru/vacancy/122425111          NaN        NaN     None
#
#   experience       schedule        employment
# 0  Нет опыта    Полный день  Полная занятость
# 1  Нет опыта  Гибкий график  Полная занятость
# 2  Нет опыта    Полный день  Полная занятость
# 3  Нет опыта    Полный день  Полная занятость
# 4  Нет опыта    Полный день  Полная занятость
