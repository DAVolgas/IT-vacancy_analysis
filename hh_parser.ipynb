# %%
import aiohttp
import asyncio
import pandas as pd
import random
import time
from datetime import datetime, timedelta, timezone
import logging

# %%
# === Настройки ===
header = {'User-Agent': 'HH-Data-Coll/v1.0 (contact 135861v@mail.ru)'}
area_id_russia = 113
per_page = 100
max_pages = 100
semaphore = asyncio.Semaphore(5)

# Опыт
experiences = ['noExperience', 'between1And3', 'between3And6', 'moreThan6']

# Настройки логгирования
log_filename = f"hh_parser_log_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",  
    handlers=[
        logging.FileHandler(log_filename, encoding="utf-8"), 
        logging.StreamHandler()
    ]
)

def log_elapsed_time(start, task="Code"):
    end = time.perf_counter()
    elapsed = end - start
    mins, secs = divmod(elapsed, 60)
    hrs, mins = divmod(mins, 60)
    logging.info(f"⏱ Время выполнения ({task}): {int(hrs):02d}:{int(mins):02d}:{secs:.2f} секунд")


# Период: последние 30 дней с шагом 7 дней
def get_date_ranges(days=30, step=7):
    today = datetime.now(timezone.utc).date()
    start_date = today - timedelta(days=days)
    ranges = []
    current = start_date
    while current < today:
        end = min(current + timedelta(days=step), today)
        ranges.append((current.isoformat(), end.isoformat()))
        current = end
    return ranges

# RateLimiter
class RateLimiter:
    def __init__(self, max_rps=3, long_pause_every=500, long_pause_duration=60):
        self.max_rps = max_rps
        self.long_pause_every = long_pause_every
        self.long_pause_duration = long_pause_duration
        self.last_request = None
        self.request_count = 0
        self.lock = asyncio.Lock()

    async def wait(self):
        async with self.lock:
            now = time.monotonic()
            if self.last_request is not None:
                elapsed = now - self.last_request
                delay = max(0, 1.0 / self.max_rps - elapsed)
                if delay > 0:
                    await asyncio.sleep(delay)
            self.last_request = time.monotonic()
            self.request_count += 1
            if self.request_count % self.long_pause_every == 0:
                logging.info(f"Долгая пауза {self.long_pause_duration} сек после {self.request_count} запросов...")
                await asyncio.sleep(self.long_pause_duration)

limiter = RateLimiter()

# %%
#=== Функции сбора вакансий ===
# Получение IT-ролей
async def fetch_it_roles():
    url = 'https://api.hh.ru/professional_roles'
    async with aiohttp.ClientSession(headers=header) as session:
        async with session.get(url) as response:
            response.raise_for_status()
            data = await response.json()
            for cat in data['categories']:
                if int(cat['id']) == 11:
                    roles = [
                        {'id': int(role['id']), 'name': role['name']}
                        for role in cat['roles']
                        if int(role['id']) not in [12, 25, 34, 155]
                    ]
                    logging.info(f'🔹 Найдено {len(roles)} IT-ролей')
                    return roles
            return []

# Загрузка одной страницы
async def fetch_page(session, params, page, desc):
    params['page'] = page
    await limiter.wait()
    try:
        async with semaphore:
            async with session.get('https://api.hh.ru/vacancies', params=params) as response:
                if response.status == 403:
                    logging.warning(f"🚫 Ошибка 403 на странице {page} — {desc}")
                    return None
                response.raise_for_status()
                return await response.json()
    except Exception as e:
        logging.warning(f"⚠️ Ошибка на странице {page} — {desc}: {e}")
        await asyncio.sleep(random.uniform(1.0, 2.0))
        return None

# Сбор вакансий по комбинации ролей, опыта и дат
async def fetch_vacancies(session, role_id, role_name, experience, date_from, date_to):
    desc = f"роль '{role_name}', опыт '{experience}', {date_from}–{date_to}"
    vacancies = []
    params = {
        'professional_role': role_id,
        'area': area_id_russia,
        'experience': experience,
        'date_from': date_from,
        'date_to': date_to,
        'per_page': per_page,
    }

    for page in range(max_pages):
        data = await fetch_page(session, params, page, desc)
        if data is None:
            break
        items = data.get('items', [])
        if not items:
            break
        vacancies.extend(items)
        if page >= data.get('pages', 0) - 1:
            break
        await asyncio.sleep(random.uniform(0.3, 0.6))

    logging.info(f"✅ Собрано {len(vacancies)} вакансий — {desc}")
    return vacancies

# Основной сбор данных
async def collect_vacancies_async():
    all_vacancies = []
    date_ranges = get_date_ranges()
    roles = await fetch_it_roles()

    async with aiohttp.ClientSession(headers=header) as session:
        for role in roles:
            logging.info(f"\n== Роль: {role['name']} (ID {role['id']}) ==")
            for exp in experiences:
                for date_from, date_to in date_ranges:
                    batch = await fetch_vacancies(session, role['id'], role['name'], exp, date_from, date_to)
                    all_vacancies.extend(batch)

    logging.info(f"\n🚀 Всего собрано {len(all_vacancies)} вакансий")
    return all_vacancies

# Преобразование вакансий в DataFrame
def extract_vacancy_data(raw_vacancies):
    extracted = []
    for v in raw_vacancies:
        area_info = v.get('area', {})
        extracted.append({
            'id': v.get('id'),
            'name': v.get('name'),
            'area': area_info.get('name'),
            'area_id': area_info.get('id'),
            'employer': v.get('employer', {}).get('name'),
            'published_at': v.get('published_at'),
            'created_at': v.get('created_at'),
            'closed_at': v.get('closed_at'),
            'archived': v.get('archived'),
            'url': v.get('alternate_url'),
            'salary_from': v.get('salary', {}).get('from') if v.get('salary') else None,
            'salary_to': v.get('salary', {}).get('to') if v.get('salary') else None,
            'currency': v.get('salary', {}).get('currency') if v.get('salary') else None,
            'experience': v.get('experience', {}).get('name'),
            'schedule': v.get('schedule', {}).get('name'),
            'employment': v.get('employment', {}).get('name'),
        })
    return pd.DataFrame(extracted)

# %%
# Запуск сбора вакансий
start = time.perf_counter()
raw_vacancies = await collect_vacancies_async()
df = extract_vacancy_data(raw_vacancies)
log_elapsed_time(start, "hh_parser")
# Out:
# 2025-07-20 13:25:38,729 [INFO] 🔹 Найдено 21 IT-ролей
# 2025-07-20 13:25:38,730 [INFO]
# == Роль: BI-аналитик, аналитик данных (ID 156) ==
# 2025-07-20 13:25:39,284 [INFO] ✅ Собрано 34 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:25:39,632 [INFO] ✅ Собрано 22 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:25:40,175 [INFO] ✅ Собрано 51 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:25:41,203 [INFO] ✅ Собрано 59 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:25:42,754 [INFO] ✅ Собрано 18 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:25:44,517 [INFO] ✅ Собрано 114 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:25:47,313 [INFO] ✅ Собрано 158 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:25:49,736 [INFO] ✅ Собрано 168 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:25:52,725 [INFO] ✅ Собрано 256 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:25:54,718 [INFO] ✅ Собрано 93 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:25:56,684 [INFO] ✅ Собрано 77 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:25:59,387 [INFO] ✅ Собрано 100 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:26:02,671 [INFO] ✅ Собрано 103 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:26:05,571 [INFO] ✅ Собрано 186 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:26:09,459 [INFO] ✅ Собрано 55 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:26:12,836 [INFO] ✅ Собрано 8 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:26:14,182 [INFO] ✅ Собрано 9 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:26:17,625 [INFO] ✅ Собрано 14 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:26:18,413 [INFO] ✅ Собрано 15 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:26:20,804 [INFO] ✅ Собрано 7 вакансий — роль 'BI-аналитик, аналитик данных', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:26:20,806 [INFO]
# == Роль: DevOps-инженер (ID 160) ==
# 2025-07-20 13:26:22,364 [INFO] ✅ Собрано 4 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:26:23,699 [INFO] ✅ Собрано 13 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:26:25,190 [INFO] ✅ Собрано 10 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:26:28,556 [INFO] ✅ Собрано 17 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:26:29,903 [INFO] ✅ Собрано 4 вакансий — роль 'DevOps-инженер', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:26:31,012 [INFO] ✅ Собрано 53 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:26:32,362 [INFO] ✅ Собрано 62 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:26:32,988 [INFO] ✅ Собрано 87 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:26:35,712 [INFO] ✅ Собрано 103 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:26:36,250 [INFO] ✅ Собрано 45 вакансий — роль 'DevOps-инженер', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:26:39,888 [INFO] ✅ Собрано 123 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:26:42,476 [INFO] ✅ Собрано 159 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:26:46,317 [INFO] ✅ Собрано 163 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:26:48,990 [INFO] ✅ Собрано 215 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:26:49,551 [INFO] ✅ Собрано 78 вакансий — роль 'DevOps-инженер', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:26:50,939 [INFO] ✅ Собрано 18 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:26:52,214 [INFO] ✅ Собрано 28 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:26:53,372 [INFO] ✅ Собрано 30 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:26:54,883 [INFO] ✅ Собрано 45 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:26:55,742 [INFO] ✅ Собрано 17 вакансий — роль 'DevOps-инженер', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:26:55,743 [INFO]
# == Роль: Аналитик (ID 10) ==
# 2025-07-20 13:26:56,670 [INFO] ✅ Собрано 39 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:26:58,726 [INFO] ✅ Собрано 82 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:27:00,454 [INFO] ✅ Собрано 101 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:27:04,735 [INFO] ✅ Собрано 200 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:27:07,006 [INFO] ✅ Собрано 112 вакансий — роль 'Аналитик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:27:11,009 [INFO] ✅ Собрано 331 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:27:17,443 [INFO] ✅ Собрано 419 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:27:25,996 [INFO] ✅ Собрано 510 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:27:34,482 [INFO] ✅ Собрано 823 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:27:38,193 [INFO] ✅ Собрано 306 вакансий — роль 'Аналитик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:27:40,189 [INFO] ✅ Собрано 195 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:27:43,330 [INFO] ✅ Собрано 261 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:27:46,654 [INFO] ✅ Собрано 311 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:27:55,149 [INFO] ✅ Собрано 480 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:27:58,741 [INFO] ✅ Собрано 164 вакансий — роль 'Аналитик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:27:59,501 [INFO] ✅ Собрано 13 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:01,414 [INFO] ✅ Собрано 35 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:02,975 [INFO] ✅ Собрано 31 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:05,180 [INFO] ✅ Собрано 36 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:06,959 [INFO] ✅ Собрано 10 вакансий — роль 'Аналитик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:06,961 [INFO]
# == Роль: Бизнес-аналитик (ID 150) ==
# 2025-07-20 13:28:07,847 [INFO] ✅ Собрано 19 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:28:09,555 [INFO] ✅ Собрано 23 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:28:10,603 [INFO] ✅ Собрано 23 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:28:11,478 [INFO] ✅ Собрано 27 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:28:11,868 [INFO] ✅ Собрано 14 вакансий — роль 'Бизнес-аналитик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:28:13,463 [INFO] ✅ Собрано 110 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:28:15,169 [INFO] ✅ Собрано 132 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:28:16,781 [INFO] ✅ Собрано 195 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:28:19,427 [INFO] ✅ Собрано 269 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:28:19,921 [INFO] ✅ Собрано 100 вакансий — роль 'Бизнес-аналитик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:28:20,579 [INFO] ✅ Собрано 98 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:21,961 [INFO] ✅ Собрано 114 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:23,495 [INFO] ✅ Собрано 157 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:25,645 [INFO] ✅ Собрано 233 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:26,277 [INFO] ✅ Собрано 66 вакансий — роль 'Бизнес-аналитик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:26,671 [INFO] ✅ Собрано 17 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:27,588 [INFO] ✅ Собрано 11 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:28,114 [INFO] ✅ Собрано 19 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:28,542 [INFO] ✅ Собрано 20 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:29,093 [INFO] ✅ Собрано 12 вакансий — роль 'Бизнес-аналитик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:29,095 [INFO]
# == Роль: Дата-сайентист (ID 165) ==
# 2025-07-20 13:28:29,559 [INFO] ✅ Собрано 3 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:28:29,883 [INFO] ✅ Собрано 9 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:28:30,348 [INFO] ✅ Собрано 11 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:28:31,716 [INFO] ✅ Собрано 12 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:28:32,366 [INFO] ✅ Собрано 6 вакансий — роль 'Дата-сайентист', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:28:32,684 [INFO] ✅ Собрано 31 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:28:33,466 [INFO] ✅ Собрано 35 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:28:34,239 [INFO] ✅ Собрано 33 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:28:35,518 [INFO] ✅ Собрано 59 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:28:36,473 [INFO] ✅ Собрано 22 вакансий — роль 'Дата-сайентист', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:28:38,160 [INFO] ✅ Собрано 56 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:39,016 [INFO] ✅ Собрано 62 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:40,243 [INFO] ✅ Собрано 90 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:41,813 [INFO] ✅ Собрано 140 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:42,162 [INFO] ✅ Собрано 50 вакансий — роль 'Дата-сайентист', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:42,645 [INFO] ✅ Собрано 18 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:43,246 [INFO] ✅ Собрано 12 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:43,841 [INFO] ✅ Собрано 17 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:45,275 [INFO] ✅ Собрано 15 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:45,807 [INFO] ✅ Собрано 5 вакансий — роль 'Дата-сайентист', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:45,814 [INFO]
# == Роль: Директор по информационным технологиям (CIO) (ID 36) ==
# 2025-07-20 13:28:47,028 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:28:47,809 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:28:48,892 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:28:49,287 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:28:49,438 [INFO] ✅ Собрано 0 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:28:49,919 [INFO] ✅ Собрано 9 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:28:50,164 [INFO] ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:28:50,537 [INFO] ✅ Собрано 8 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:28:51,153 [INFO] ✅ Собрано 10 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:28:51,944 [INFO] ✅ Собрано 4 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:28:52,799 [INFO] ✅ Собрано 18 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:54,832 [INFO] ✅ Собрано 26 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:56,165 [INFO] ✅ Собрано 22 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:56,622 [INFO] ✅ Собрано 43 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:56,818 [INFO] ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:58,225 [INFO] ✅ Собрано 12 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:28:58,550 [INFO] ✅ Собрано 11 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:28:58,776 [INFO] ✅ Собрано 8 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:28:59,140 [INFO] ✅ Собрано 17 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:28:59,443 [INFO] ✅ Собрано 5 вакансий — роль 'Директор по информационным технологиям (CIO)', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:28:59,445 [INFO]
# == Роль: Менеджер продукта (ID 73) ==
# 2025-07-20 13:28:59,865 [INFO] ✅ Собрано 11 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:29:00,300 [INFO] ✅ Собрано 13 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:29:00,696 [INFO] ✅ Собрано 28 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:29:01,134 [INFO] ✅ Собрано 50 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:29:01,430 [INFO] ✅ Собрано 29 вакансий — роль 'Менеджер продукта', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:29:02,857 [INFO] ✅ Собрано 131 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:29:04,480 [INFO] ✅ Собрано 153 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:29:06,117 [INFO] ✅ Собрано 179 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:29:10,723 [INFO] ✅ Собрано 375 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:29:14,467 [INFO] ✅ Собрано 178 вакансий — роль 'Менеджер продукта', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:29:16,987 [INFO] ✅ Собрано 140 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:29:19,855 [INFO] ✅ Собрано 204 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:29:22,784 [INFO] ✅ Собрано 220 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:29:26,141 [INFO] ✅ Собрано 329 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:29:27,401 [INFO] ✅ Собрано 142 вакансий — роль 'Менеджер продукта', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:29:27,750 [INFO] ✅ Собрано 25 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:29:28,077 [INFO] ✅ Собрано 32 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:29:28,440 [INFO] ✅ Собрано 32 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:29:28,856 [INFO] ✅ Собрано 61 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:29:29,101 [INFO] ✅ Собрано 23 вакансий — роль 'Менеджер продукта', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:29:29,105 [INFO]
# == Роль: Программист, разработчик (ID 96) ==
# 2025-07-20 13:29:30,522 [INFO] ✅ Собрано 143 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:29:31,986 [INFO] ✅ Собрано 189 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:29:33,275 [INFO] ✅ Собрано 194 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:29:36,392 [INFO] ✅ Собрано 305 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:29:38,112 [INFO] ✅ Собрано 144 вакансий — роль 'Программист, разработчик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:29:46,015 [INFO] ✅ Собрано 719 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:29:55,309 [INFO] ✅ Собрано 948 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:30:06,519 [INFO] ✅ Собрано 1125 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:30:22,837 [INFO] ✅ Собрано 1661 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:30:29,855 [INFO] ✅ Собрано 716 вакансий — роль 'Программист, разработчик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:30:40,068 [INFO] ✅ Собрано 949 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:30:51,078 [INFO] ✅ Собрано 1035 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:04,561 [INFO] ✅ Собрано 1205 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:24,179 [INFO] ✅ Собрано 1982 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:31:32,011 [INFO] ✅ Собрано 848 вакансий — роль 'Программист, разработчик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:31:33,443 [INFO] ✅ Собрано 171 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:31:34,686 [INFO] ✅ Собрано 151 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:36,131 [INFO] ✅ Собрано 195 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:39,660 [INFO] ✅ Собрано 337 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:31:40,909 [INFO] ✅ Собрано 159 вакансий — роль 'Программист, разработчик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:31:40,910 [INFO]
# == Роль: Продуктовый аналитик (ID 164) ==
# 2025-07-20 13:31:41,061 [INFO] ✅ Собрано 0 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:31:41,435 [INFO] ✅ Собрано 3 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:31:41,798 [INFO] ✅ Собрано 4 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:31:42,100 [INFO] ✅ Собрано 11 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:31:42,459 [INFO] ✅ Собрано 1 вакансий — роль 'Продуктовый аналитик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:31:42,941 [INFO] ✅ Собрано 28 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:31:43,275 [INFO] ✅ Собрано 39 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:31:43,619 [INFO] ✅ Собрано 38 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:31:44,031 [INFO] ✅ Собрано 83 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:31:44,263 [INFO] ✅ Собрано 29 вакансий — роль 'Продуктовый аналитик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:31:44,576 [INFO] ✅ Собрано 28 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:31:45,134 [INFO] ✅ Собрано 40 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:45,567 [INFO] ✅ Собрано 50 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:45,908 [INFO] ✅ Собрано 55 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:31:46,153 [INFO] ✅ Собрано 21 вакансий — роль 'Продуктовый аналитик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:31:46,500 [INFO] ✅ Собрано 5 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:31:46,775 [INFO] ✅ Собрано 3 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:47,182 [INFO] ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:47,439 [INFO] ✅ Собрано 2 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:31:47,734 [INFO] ✅ Собрано 0 вакансий — роль 'Продуктовый аналитик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:31:47,736 [INFO]
# == Роль: Руководитель группы разработки (ID 104) ==
# 2025-07-20 13:31:48,145 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:31:48,487 [INFO] ✅ Собрано 2 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:31:48,739 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:31:49,129 [INFO] ✅ Собрано 6 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:31:49,480 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель группы разработки', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:31:49,844 [INFO] ✅ Собрано 20 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:31:50,215 [INFO] ✅ Собрано 19 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:31:50,574 [INFO] ✅ Собрано 25 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:31:50,995 [INFO] ✅ Собрано 53 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:31:51,350 [INFO] ✅ Собрано 21 вакансий — роль 'Руководитель группы разработки', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:31:52,780 [INFO] ✅ Собрано 107 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:31:54,155 [INFO] ✅ Собрано 105 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:55,635 [INFO] ✅ Собрано 108 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:57,221 [INFO] ✅ Собрано 197 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:31:57,591 [INFO] ✅ Собрано 66 вакансий — роль 'Руководитель группы разработки', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:31:58,019 [INFO] ✅ Собрано 58 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:31:58,393 [INFO] ✅ Собрано 54 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:31:58,800 [INFO] ✅ Собрано 66 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:31:59,963 [INFO] ✅ Собрано 114 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:32:00,523 [INFO] ✅ Собрано 37 вакансий — роль 'Руководитель группы разработки', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:32:00,524 [INFO]
# == Роль: Руководитель отдела аналитики (ID 157) ==
# 2025-07-20 13:32:00,689 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:32:01,305 [INFO] ✅ Собрано 1 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:32:01,543 [INFO] ✅ Собрано 3 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:32:01,819 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:32:02,182 [INFO] ✅ Собрано 0 вакансий — роль 'Руководитель отдела аналитики', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:32:02,567 [INFO] ✅ Собрано 14 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:32:02,938 [INFO] ✅ Собрано 14 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:32:03,277 [INFO] ✅ Собрано 17 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:32:03,589 [INFO] ✅ Собрано 23 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:32:03,860 [INFO] ✅ Собрано 8 вакансий — роль 'Руководитель отдела аналитики', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:32:04,299 [INFO] ✅ Собрано 23 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:32:04,755 [INFO] ✅ Собрано 36 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:32:05,146 [INFO] ✅ Собрано 39 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:32:05,661 [INFO] ✅ Собрано 89 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:32:06,041 [INFO] ✅ Собрано 33 вакансий — роль 'Руководитель отдела аналитики', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:32:06,329 [INFO] ✅ Собрано 15 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:32:06,686 [INFO] ✅ Собрано 14 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:32:07,059 [INFO] ✅ Собрано 25 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:32:07,361 [INFO] ✅ Собрано 21 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:32:07,697 [INFO] ✅ Собрано 5 вакансий — роль 'Руководитель отдела аналитики', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:32:07,700 [INFO]
# == Роль: Руководитель проектов (ID 107) ==
# 2025-07-20 13:32:08,263 [INFO] ✅ Собрано 52 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:32:08,726 [INFO] ✅ Собрано 46 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:32:09,180 [INFO] ✅ Собрано 68 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:32:09,835 [INFO] ✅ Собрано 93 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:32:10,311 [INFO] ✅ Собрано 54 вакансий — роль 'Руководитель проектов', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:32:13,918 [INFO] ✅ Собрано 306 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:32:18,297 [INFO] ✅ Собрано 414 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:32:23,096 [INFO] ✅ Собрано 440 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:32:38,316 [INFO] ✅ Собрано 874 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:32:42,217 [INFO] ✅ Собрано 432 вакансий — роль 'Руководитель проектов', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:32:45,979 [INFO] ✅ Собрано 340 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:32:50,710 [INFO] ✅ Собрано 470 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:32:56,077 [INFO] ✅ Собрано 536 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:33:04,492 [INFO] ✅ Собрано 782 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:33:07,895 [INFO] ✅ Собрано 343 вакансий — роль 'Руководитель проектов', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:33:08,355 [INFO] ✅ Собрано 70 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:33:08,798 [INFO] ✅ Собрано 95 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:33:09,224 [INFO] ✅ Собрано 90 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:33:10,704 [INFO] ✅ Собрано 145 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:33:11,038 [INFO] ✅ Собрано 71 вакансий — роль 'Руководитель проектов', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:33:11,038 [INFO]
# == Роль: Сетевой инженер (ID 112) ==
# 2025-07-20 13:33:11,327 [INFO] ✅ Собрано 15 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:33:11,663 [INFO] ✅ Собрано 24 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:33:12,140 [INFO] ✅ Собрано 31 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:33:12,460 [INFO] ✅ Собрано 45 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:33:12,705 [INFO] ✅ Собрано 10 вакансий — роль 'Сетевой инженер', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:33:13,251 [INFO] ✅ Собрано 71 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:33:13,842 [INFO] ✅ Собрано 83 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:33:14,421 [INFO] ✅ Собрано 80 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:33:15,751 [INFO] ✅ Собрано 154 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:33:15,754 [INFO] Долгая пауза 60 сек после 500 запросов...
# 2025-07-20 13:34:16,350 [INFO] ✅ Собрано 43 вакансий — роль 'Сетевой инженер', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:34:16,861 [INFO] ✅ Собрано 52 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:34:17,331 [INFO] ✅ Собрано 76 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:34:17,876 [INFO] ✅ Собрано 58 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:34:19,077 [INFO] ✅ Собрано 118 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:34:19,568 [INFO] ✅ Собрано 33 вакансий — роль 'Сетевой инженер', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:34:19,838 [INFO] ✅ Собрано 8 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:34:20,102 [INFO] ✅ Собрано 10 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:34:20,498 [INFO] ✅ Собрано 6 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:34:20,831 [INFO] ✅ Собрано 25 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:34:21,114 [INFO] ✅ Собрано 9 вакансий — роль 'Сетевой инженер', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:34:21,115 [INFO]
# == Роль: Системный администратор (ID 113) ==
# 2025-07-20 13:34:21,723 [INFO] ✅ Собрано 88 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:34:23,025 [INFO] ✅ Собрано 124 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:34:24,458 [INFO] ✅ Собрано 114 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:34:26,673 [INFO] ✅ Собрано 210 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:34:27,232 [INFO] ✅ Собрано 77 вакансий — роль 'Системный администратор', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:34:32,690 [INFO] ✅ Собрано 477 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:34:39,711 [INFO] ✅ Собрано 639 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:34:46,253 [INFO] ✅ Собрано 560 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:34:56,137 [INFO] ✅ Собрано 958 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:34:59,764 [INFO] ✅ Собрано 378 вакансий — роль 'Системный администратор', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:35:02,032 [INFO] ✅ Собрано 214 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:04,731 [INFO] ✅ Собрано 259 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:08,023 [INFO] ✅ Собрано 313 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:13,019 [INFO] ✅ Собрано 517 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:14,975 [INFO] ✅ Собрано 230 вакансий — роль 'Системный администратор', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:15,483 [INFO] ✅ Собрано 28 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:15,972 [INFO] ✅ Собрано 47 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:16,519 [INFO] ✅ Собрано 34 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:16,908 [INFO] ✅ Собрано 68 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:17,147 [INFO] ✅ Собрано 25 вакансий — роль 'Системный администратор', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:17,149 [INFO]
# == Роль: Системный аналитик (ID 148) ==
# 2025-07-20 13:35:17,508 [INFO] ✅ Собрано 19 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:35:17,851 [INFO] ✅ Собрано 16 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:35:18,227 [INFO] ✅ Собрано 20 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:35:18,605 [INFO] ✅ Собрано 34 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:35:18,831 [INFO] ✅ Собрано 12 вакансий — роль 'Системный аналитик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:35:19,568 [INFO] ✅ Собрано 97 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:35:20,915 [INFO] ✅ Собрано 124 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:35:22,238 [INFO] ✅ Собрано 120 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:35:23,720 [INFO] ✅ Собрано 183 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:35:24,165 [INFO] ✅ Собрано 65 вакансий — роль 'Системный аналитик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:35:25,422 [INFO] ✅ Собрано 138 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:26,806 [INFO] ✅ Собрано 157 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:28,198 [INFO] ✅ Собрано 194 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:30,992 [INFO] ✅ Собрано 312 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:32,433 [INFO] ✅ Собрано 102 вакансий — роль 'Системный аналитик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:32,670 [INFO] ✅ Собрано 17 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:33,023 [INFO] ✅ Собрано 11 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:33,378 [INFO] ✅ Собрано 17 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:33,774 [INFO] ✅ Собрано 29 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:33,995 [INFO] ✅ Собрано 11 вакансий — роль 'Системный аналитик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:33,997 [INFO]
# == Роль: Системный инженер (ID 114) ==
# 2025-07-20 13:35:34,385 [INFO] ✅ Собрано 16 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:35:34,728 [INFO] ✅ Собрано 13 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:35:35,146 [INFO] ✅ Собрано 36 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:35:35,493 [INFO] ✅ Собрано 40 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:35:35,760 [INFO] ✅ Собрано 22 вакансий — роль 'Системный инженер', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:35:36,428 [INFO] ✅ Собрано 74 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:35:36,978 [INFO] ✅ Собрано 98 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:35:38,556 [INFO] ✅ Собрано 133 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:35:40,131 [INFO] ✅ Собрано 180 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:35:40,554 [INFO] ✅ Собрано 78 вакансий — роль 'Системный инженер', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:35:41,229 [INFO] ✅ Собрано 64 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:41,646 [INFO] ✅ Собрано 71 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:42,148 [INFO] ✅ Собрано 78 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:43,468 [INFO] ✅ Собрано 139 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:44,097 [INFO] ✅ Собрано 53 вакансий — роль 'Системный инженер', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:44,332 [INFO] ✅ Собрано 11 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:35:44,673 [INFO] ✅ Собрано 8 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:35:45,021 [INFO] ✅ Собрано 8 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:35:45,411 [INFO] ✅ Собрано 12 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:35:45,651 [INFO] ✅ Собрано 2 вакансий — роль 'Системный инженер', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:35:45,653 [INFO]
# == Роль: Специалист по информационной безопасности (ID 116) ==
# 2025-07-20 13:35:46,434 [INFO] ✅ Собрано 78 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:35:47,800 [INFO] ✅ Собрано 107 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:35:48,476 [INFO] ✅ Собрано 96 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:35:49,551 [INFO] ✅ Собрано 103 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:35:49,968 [INFO] ✅ Собрано 32 вакансий — роль 'Специалист по информационной безопасности', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:35:53,636 [INFO] ✅ Собрано 314 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:35:57,272 [INFO] ✅ Собрано 371 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:36:00,707 [INFO] ✅ Собрано 376 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:36:07,005 [INFO] ✅ Собрано 601 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:36:09,391 [INFO] ✅ Собрано 208 вакансий — роль 'Специалист по информационной безопасности', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:36:11,880 [INFO] ✅ Собрано 207 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:36:14,453 [INFO] ✅ Собрано 266 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:36:17,616 [INFO] ✅ Собрано 303 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:36:21,922 [INFO] ✅ Собрано 446 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:36:23,332 [INFO] ✅ Собрано 139 вакансий — роль 'Специалист по информационной безопасности', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:36:23,619 [INFO] ✅ Собрано 23 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:36:24,098 [INFO] ✅ Собрано 42 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:36:24,354 [INFO] ✅ Собрано 23 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:36:24,762 [INFO] ✅ Собрано 37 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:36:25,003 [INFO] ✅ Собрано 18 вакансий — роль 'Специалист по информационной безопасности', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:36:25,004 [INFO]
# == Роль: Специалист технической поддержки (ID 121) ==
# 2025-07-20 13:36:29,894 [INFO] ✅ Собрано 432 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:36:36,712 [INFO] ✅ Собрано 682 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:36:44,215 [INFO] ✅ Собрано 753 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:36:58,686 [INFO] ✅ Собрано 1326 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:37:03,203 [INFO] ✅ Собрано 493 вакансий — роль 'Специалист технической поддержки', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:37:07,685 [INFO] ✅ Собрано 436 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:37:14,597 [INFO] ✅ Собрано 653 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:37:22,375 [INFO] ✅ Собрано 776 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:37:36,284 [INFO] ✅ Собрано 1357 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:37:43,867 [INFO] ✅ Собрано 548 вакансий — роль 'Специалист технической поддержки', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:37:45,542 [INFO] ✅ Собрано 92 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:37:47,951 [INFO] ✅ Собрано 120 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:37:49,489 [INFO] ✅ Собрано 144 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:37:52,182 [INFO] ✅ Собрано 218 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:37:52,728 [INFO] ✅ Собрано 78 вакансий — роль 'Специалист технической поддержки', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:37:53,213 [INFO] ✅ Собрано 10 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:37:53,454 [INFO] ✅ Собрано 4 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:37:53,744 [INFO] ✅ Собрано 6 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:37:54,163 [INFO] ✅ Собрано 18 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:37:54,417 [INFO] ✅ Собрано 3 вакансий — роль 'Специалист технической поддержки', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:37:54,421 [INFO]
# == Роль: Тестировщик (ID 124) ==
# 2025-07-20 13:37:54,912 [INFO] ✅ Собрано 31 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:37:55,329 [INFO] ✅ Собрано 40 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:37:55,794 [INFO] ✅ Собрано 42 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:37:56,217 [INFO] ✅ Собрано 73 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:37:56,504 [INFO] ✅ Собрано 24 вакансий — роль 'Тестировщик', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:37:57,859 [INFO] ✅ Собрано 133 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:38:00,041 [INFO] ✅ Собрано 214 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:38:01,437 [INFO] ✅ Собрано 147 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:38:04,032 [INFO] ✅ Собрано 293 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:38:05,162 [INFO] ✅ Собрано 135 вакансий — роль 'Тестировщик', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:38:05,763 [INFO] ✅ Собрано 99 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:07,268 [INFO] ✅ Собрано 134 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:08,678 [INFO] ✅ Собрано 162 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:11,036 [INFO] ✅ Собрано 253 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:11,471 [INFO] ✅ Собрано 76 вакансий — роль 'Тестировщик', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:11,761 [INFO] ✅ Собрано 22 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:12,047 [INFO] ✅ Собрано 26 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:12,435 [INFO] ✅ Собрано 29 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:12,913 [INFO] ✅ Собрано 28 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:13,202 [INFO] ✅ Собрано 17 вакансий — роль 'Тестировщик', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:13,204 [INFO]
# == Роль: Технический директор (CTO) (ID 125) ==
# 2025-07-20 13:38:13,422 [INFO] ✅ Собрано 1 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:38:13,783 [INFO] ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:38:14,097 [INFO] ✅ Собрано 2 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:38:14,448 [INFO] ✅ Собрано 5 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:38:14,759 [INFO] ✅ Собрано 0 вакансий — роль 'Технический директор (CTO)', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:38:15,235 [INFO] ✅ Собрано 26 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:38:15,530 [INFO] ✅ Собрано 16 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:38:15,946 [INFO] ✅ Собрано 27 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:38:16,356 [INFO] ✅ Собрано 40 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:38:16,613 [INFO] ✅ Собрано 18 вакансий — роль 'Технический директор (CTO)', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:38:17,128 [INFO] ✅ Собрано 45 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:17,658 [INFO] ✅ Собрано 68 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:18,200 [INFO] ✅ Собрано 71 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:19,613 [INFO] ✅ Собрано 135 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:19,980 [INFO] ✅ Собрано 57 вакансий — роль 'Технический директор (CTO)', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:20,233 [INFO] ✅ Собрано 19 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:20,692 [INFO] ✅ Собрано 36 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:21,061 [INFO] ✅ Собрано 45 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:21,540 [INFO] ✅ Собрано 73 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:21,831 [INFO] ✅ Собрано 46 вакансий — роль 'Технический директор (CTO)', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:21,833 [INFO]
# == Роль: Технический писатель (ID 126) ==
# 2025-07-20 13:38:22,101 [INFO] ✅ Собрано 7 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-20–2025-06-27
# 2025-07-20 13:38:22,482 [INFO] ✅ Собрано 10 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-06-27–2025-07-04
# 2025-07-20 13:38:22,771 [INFO] ✅ Собрано 5 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-04–2025-07-11
# 2025-07-20 13:38:23,119 [INFO] ✅ Собрано 17 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-11–2025-07-18
# 2025-07-20 13:38:23,505 [INFO] ✅ Собрано 5 вакансий — роль 'Технический писатель', опыт 'noExperience', 2025-07-18–2025-07-20
# 2025-07-20 13:38:23,930 [INFO] ✅ Собрано 38 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-20–2025-06-27
# 2025-07-20 13:38:24,305 [INFO] ✅ Собрано 45 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-06-27–2025-07-04
# 2025-07-20 13:38:24,809 [INFO] ✅ Собрано 64 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-04–2025-07-11
# 2025-07-20 13:38:25,277 [INFO] ✅ Собрано 97 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-11–2025-07-18
# 2025-07-20 13:38:25,545 [INFO] ✅ Собрано 34 вакансий — роль 'Технический писатель', опыт 'between1And3', 2025-07-18–2025-07-20
# 2025-07-20 13:38:25,901 [INFO] ✅ Собрано 30 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:26,334 [INFO] ✅ Собрано 29 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:26,879 [INFO] ✅ Собрано 36 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:27,222 [INFO] ✅ Собрано 41 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:27,456 [INFO] ✅ Собрано 22 вакансий — роль 'Технический писатель', опыт 'between3And6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:27,805 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-20–2025-06-27
# 2025-07-20 13:38:28,067 [INFO] ✅ Собрано 4 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-06-27–2025-07-04
# 2025-07-20 13:38:28,393 [INFO] ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-04–2025-07-11
# 2025-07-20 13:38:28,747 [INFO] ✅ Собрано 2 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-11–2025-07-18
# 2025-07-20 13:38:29,043 [INFO] ✅ Собрано 0 вакансий — роль 'Технический писатель', опыт 'moreThan6', 2025-07-18–2025-07-20
# 2025-07-20 13:38:29,046 [INFO]
# 🚀 Всего собрано 57239 вакансий
# 2025-07-20 13:38:29,442 [INFO] ⏱ Время выполнения (hh_parser): 00:12:54.10 секунд

# %%
df.head()
# Out:
#           id                     name             area area_id  \
# 0  120865772  Младший аналитик данных  Санкт-Петербург       2
# 1  122059039  Младший аналитик данных           Москва       1
# 2  121943475          Аналитик данных            Томск      90
# 3  121987787          Аналитик данных           Брянск      19
# 4  121972260          Аналитик данных           Рязань      77
#
#                  employer              published_at                created_at  \
# 0           Topface Media  2025-06-24T16:59:10+0300  2025-06-24T16:59:10+0300
# 1             МКК Финмолл  2025-06-25T14:52:10+0300  2025-06-25T14:52:10+0300
# 2                 Звонарь  2025-06-23T12:13:10+0300  2025-06-23T12:13:10+0300
# 3             Баннер Стат  2025-06-24T09:39:55+0300  2025-06-24T09:39:55+0300
# 4  Банк Прио-Внешторгбанк  2025-06-27T12:20:47+0300  2025-06-27T12:20:47+0300
#
#   closed_at  archived                              url  salary_from  \
# 0      None     False  https://hh.ru/vacancy/120865772      30000.0
# 1      None     False  https://hh.ru/vacancy/122059039      90000.0
# 2      None     False  https://hh.ru/vacancy/121943475      60000.0
# 3      None     False  https://hh.ru/vacancy/121987787      50000.0
# 4      None     False  https://hh.ru/vacancy/121972260          NaN
#
#    salary_to currency experience          schedule        employment
# 0    40000.0      RUR  Нет опыта  Удаленная работа  Полная занятость
# 1        NaN      RUR  Нет опыта       Полный день  Полная занятость
# 2    80000.0      RUR  Нет опыта  Удаленная работа  Полная занятость
# 3        NaN      RUR  Нет опыта       Полный день  Полная занятость
# 4        NaN     None  Нет опыта       Полный день  Полная занятость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57239 entries, 0 to 57238
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            57239 non-null  object
#  1   name          57239 non-null  object
#  2   area          57239 non-null  object
#  3   area_id       57239 non-null  object
#  4   employer      57239 non-null  object
#  5   published_at  57239 non-null  object
#  6   created_at    57239 non-null  object
#  7   closed_at     0 non-null      object
#  8   archived      57239 non-null  bool
#  9   url           57239 non-null  object
#  10  salary_from   22433 non-null  float64
#  11  salary_to     13903 non-null  float64
#  12  currency      25771 non-null  object
#  13  experience    57239 non-null  object
#  14  schedule      57239 non-null  object
#  15  employment    57239 non-null  object
# dtypes: bool(1), float64(2), object(13)
# memory usage: 6.6+ MB
